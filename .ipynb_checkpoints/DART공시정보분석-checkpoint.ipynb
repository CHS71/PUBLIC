# %%
# 실제 인증키를 사용
auth = ''

# %% [markdown]
# # <DART검색API사용>

# %%
#DART검색API를 사용.  당일 접수 10건에 대한 정보 요청하여 xml형식으로 받아오기.

import requests # HTTP Request를 웹 브라우저가 아닌 python 에서 모듈로 가능하게 해주는 모듈
import pprint #복잡한 자료구조를 알기쉽게 표시해주는 모듈

## 요청변수:  인증키: auth 
url_tmpl = 'http://dart.fss.or.kr/api/search.xml?auth={auth}' # <당일 접수 10건> 검색API 요청주소 (xml형식) 
url = url_tmpl.format(auth=auth)

r = requests.get(url)
# pprint.pprint(r.text)  #XML형식을 확인
# Out:
# ('<?xml version="1.0" encoding="utf-8"?>\n'
#  '<result>\n'
#  '  <err_code>000</err_code>\n'
#  '  <err_msg>정상</err_msg>\n'
#  '  <page_no>1</page_no>\n'
#  '  <page_set>10</page_set>\n'
#  '  <total_count>92</total_count>\n'
#  '  <total_page>10</total_page>\n'
#  '  <list>\n'
#  '    <crp_cls>Y</crp_cls>\n'
#  '    <crp_nm>NH투자증권</crp_nm>\n'
#  '    <crp_cd>005940</crp_cd>\n'
#  '    <rpt_nm>투자설명서(일괄신고)</rpt_nm>\n'
#  '    <rcp_no>20190724000110</rcp_no>\n'
#  '    <flr_nm>NH투자증권</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk></rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>Y</crp_cls>\n'
#  '    <crp_nm>삼성에스디에스</crp_nm>\n'
#  '    <crp_cd>018260</crp_cd>\n'
#  '    <rpt_nm>동일인등출자계열회사와의상품ㆍ용역거래변경</rpt_nm>\n'
#  '    <rcp_no>20190724000108</rcp_no>\n'
#  '    <flr_nm>삼성에스디에스</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk>공</rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>Y</crp_cls>\n'
#  '    <crp_nm>현대차증권</crp_nm>\n'
#  '    <crp_cd>001500</crp_cd>\n'
#  '    <rpt_nm>투자설명서(일괄신고)</rpt_nm>\n'
#  '    <rcp_no>20190724000106</rcp_no>\n'
#  '    <flr_nm>현대차증권</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk></rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>E</crp_cls>\n'
#  '    <crp_nm>케이비증권</crp_nm>\n'
#  '    <crp_cd>00164876</crp_cd>\n'
#  '    <rpt_nm>투자설명서(일괄신고)</rpt_nm>\n'
#  '    <rcp_no>20190724000103</rcp_no>\n'
#  '    <flr_nm>케이비증권</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk></rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>Y</crp_cls>\n'
#  '    <crp_nm>NH투자증권</crp_nm>\n'
#  '    <crp_cd>005940</crp_cd>\n'
#  '    <rpt_nm>일괄신고추가서류(파생결합증권-주가연계증권)</rpt_nm>\n'
#  '    <rcp_no>20190724000107</rcp_no>\n'
#  '    <flr_nm>NH투자증권</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk></rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>E</crp_cls>\n'
#  '    <crp_nm>케이비증권</crp_nm>\n'
#  '    <crp_cd>00164876</crp_cd>\n'
#  '    <rpt_nm>일괄신고추가서류(파생결합증권-주가연계증권)</rpt_nm>\n'
#  '    <rcp_no>20190724000104</rcp_no>\n'
#  '    <flr_nm>케이비증권</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk></rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>E</crp_cls>\n'
#  '    <crp_nm>한국투자증권</crp_nm>\n'
#  '    <crp_cd>00160144</crp_cd>\n'
#  '    <rpt_nm>일괄신고추가서류(파생결합증권-주가연계증권)</rpt_nm>\n'
#  '    <rcp_no>20190724000109</rcp_no>\n'
#  '    <flr_nm>한국투자증권</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk></rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>Y</crp_cls>\n'
#  '    <crp_nm>LG유플러스</crp_nm>\n'
#  '    <crp_cd>032640</crp_cd>\n'
#  '    <rpt_nm>지속가능경영보고서등관련사항(자율공시)</rpt_nm>\n'
#  '    <rcp_no>20190724800130</rcp_no>\n'
#  '    <flr_nm>LG유플러스</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk>유</rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>Y</crp_cls>\n'
#  '    <crp_nm>메리츠종금증권</crp_nm>\n'
#  '    <crp_cd>008560</crp_cd>\n'
#  '    <rpt_nm>일괄신고추가서류(파생결합증권-주가연계증권)</rpt_nm>\n'
#  '    <rcp_no>20190724000105</rcp_no>\n'
#  '    <flr_nm>메리츠종금증권</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk></rmk>\n'
#  '  </list>\n'
#  '  <list>\n'
#  '    <crp_cls>Y</crp_cls>\n'
#  '    <crp_nm>미래에셋대우</crp_nm>\n'
#  '    <crp_cd>006800</crp_cd>\n'
#  '    <rpt_nm>투자설명서(일괄신고)</rpt_nm>\n'
#  '    <rcp_no>20190724000100</rcp_no>\n'
#  '    <flr_nm>미래에셋대우</flr_nm>\n'
#  '    <rcp_dt>20190724</rcp_dt>\n'
#  '    <rmk></rmk>\n'
#  '  </list>\n'
#  '</result>')

# %%
#DART검색API를 사용.  당일 접수 10건에 대한 정보를 요청하여 json형식으로 받아오기.
import requests

## 요청변수:  인증키: auth 
url_tmpl = 'http://dart.fss.or.kr/api/search.json?auth={auth}'# <당일 접수 10건> 검색API 요청주소 (json형식)
url = url_tmpl.format(auth=auth)
r = requests.get(url)


## json 데이터를 문자열로 변환

# print(r.text)    
# pprint.pprint(r.text)   #  pprint를 사용하여 복잡한 json형식을 알기쉽게 출력  /   json -> python자료형인 딕셔너리와 유사




## json.loads json 데이터를 dict형으로 변환
import json  # json 을 dictionary 로 변환하는 파이썬 모듈
jo = json.loads(r.text) 
pprint.pprint(jo)



## json데이터를 데이터프레임으로 변환
from pandas.io.json import json_normalize  # json_normalize: JSON 데이터 DataFrame으로 변환하는 함수

result = json_normalize(jo, 'list')
result.head(1) # 첫 1개의 데이터만 불러오기
# Out:
# {'err_code': '000',
#  'err_msg': '정상',
#  'list': [{'crp_cd': '058220',
#            'crp_cls': 'K',
#            'crp_nm': '아리온',
#            'flr_nm': '아리온',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724900175',
#            'rmk': '코',
#            'rpt_nm': '전환가액의조정(제9회차)'},
#           {'crp_cd': '210610',
#            'crp_cls': 'N',
#            'crp_nm': '소프트캠프',
#            'flr_nm': '소프트캠프',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724600174',
#            'rmk': '넥',
#            'rpt_nm': '주식명의개서정지(주주명부폐쇄)'},
#           {'crp_cd': '065420',
#            'crp_cls': 'K',
#            'crp_nm': '에스아이리소스',
#            'flr_nm': '에스아이리소스',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724900171',
#            'rmk': '코',
#            'rpt_nm': '[기재정정]주주총회소집결의'},
#           {'crp_cd': '016360',
#            'crp_cls': 'Y',
#            'crp_nm': '삼성증권',
#            'flr_nm': '삼성증권',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724000144',
#            'rmk': '',
#            'rpt_nm': '투자설명서(일괄신고)'},
#           {'crp_cd': '210610',
#            'crp_cls': 'N',
#            'crp_nm': '소프트캠프',
#            'flr_nm': '코넥스시장',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724600168',
#            'rmk': '넥',
#            'rpt_nm': '주권매매거래정지(무상증자)'},
#           {'crp_cd': '006800',
#            'crp_cls': 'Y',
#            'crp_nm': '미래에셋대우',
#            'flr_nm': '미래에셋대우',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724000148',
#            'rmk': '',
#            'rpt_nm': '일괄신고추가서류(파생결합증권-주가연계증권)'},
#           {'crp_cd': '039490',
#            'crp_cls': 'Y',
#            'crp_nm': '키움증권',
#            'flr_nm': '키움증권',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724000142',
#            'rmk': '',
#            'rpt_nm': '투자설명서(일괄신고)'},
#           {'crp_cd': '210610',
#            'crp_cls': 'N',
#            'crp_nm': '소프트캠프',
#            'flr_nm': '소프트캠프',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724000141',
#            'rmk': '',
#            'rpt_nm': '주요사항보고서(무상증자결정)'},
#           {'crp_cd': '016360',
#            'crp_cls': 'Y',
#            'crp_nm': '삼성증권',
#            'flr_nm': '삼성증권',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724000139',
#            'rmk': '',
#            'rpt_nm': '투자설명서(일괄신고)'},
#           {'crp_cd': '016360',
#            'crp_cls': 'Y',
#            'crp_nm': '삼성증권',
#            'flr_nm': '삼성증권',
#            'rcp_dt': '20190724',
#            'rcp_no': '20190724000143',
#            'rmk': '',
#            'rpt_nm': '일괄신고추가서류(기타파생결합증권)'}],
#  'page_no': 1,
#  'page_set': 10,
#  'total_count': 130,
#  'total_page': 13}
#    crp_cd crp_cls   crp_nm   flr_nm    rcp_dt          rcp_no rmk  \
# 0  058220       K      아리온      아리온  20190724  20190724900175   코
# 1  210610       N    소프트캠프    소프트캠프  20190724  20190724600174   넥
# 2  065420       K  에스아이리소스  에스아이리소스  20190724  20190724900171   코
# 3  016360       Y     삼성증권     삼성증권  20190724  20190724000144
# 4  210610       N    소프트캠프    코넥스시장  20190724  20190724600168   넥
#
#              rpt_nm
# 0     전환가액의조정(제9회차)
# 1  주식명의개서정지(주주명부폐쇄)
# 2    [기재정정]주주총회소집결의
# 3       투자설명서(일괄신고)
# 4    주권매매거래정지(무상증자)

# %%
#DART검색API를 사용.  당일 접수 100건에 대한 정보를 요청하여 json형식으로 받아오기.

##요청변수: auth , page_set
url_tmpl = 'http://dart.fss.or.kr/api/search.json?auth={auth}&page_set=100'
url = url_tmpl.format(auth=auth)
r = requests.get(url)
jo = json.loads(r.text)
result = json_normalize(jo, 'list')
result.head()
# Out:
#    crp_cd crp_cls   crp_nm   flr_nm    rcp_dt          rcp_no rmk  \
# 0  281310       N  바이오시네틱스  바이오시네틱스  20190724  20190724600177   넥
# 1  058220       K      아리온      아리온  20190724  20190724900175   코
# 2  210610       N    소프트캠프    소프트캠프  20190724  20190724600174   넥
# 3  065420       K  에스아이리소스  에스아이리소스  20190724  20190724900171   코
# 4  016360       Y     삼성증권     삼성증권  20190724  20190724000144
#
#              rpt_nm
# 0     기업설명회(IR)개최결과
# 1     전환가액의조정(제9회차)
# 2  주식명의개서정지(주주명부폐쇄)
# 3    [기재정정]주주총회소집결의
# 4       투자설명서(일괄신고)

# %%
#DART검색API를 사용. 회사의 전체 사업+반기+분기보고서 100건에 대한 정보 요청.

#요청변수: auth 인증키 , crp_cd 회사종목코드 , start_dt 검색시작 접수일자 , bsn_tp 공시보고서종류 , page_set 페이지당 건수(1~100) 기본값 : 10
url_tmpl = 'http://dart.fss.or.kr/api/search.json?auth={auth}&crp_cd={code}&start_dt=19990101&bsn_tp=A001&bsn_tp=A002&bsn_tp=A003&page_set=100'
url = url_tmpl.format(auth=auth, code='005930')
r = requests.get(url)
jo = json.loads(r.text) #딕셔너리 변환
result = json_normalize(jo, 'list') # 데이터프레임 변환
print('총', len(result), '건')
result.head()
# Out:
# 총 85 건
#    crp_cd crp_cls crp_nm flr_nm    rcp_dt          rcp_no rmk           rpt_nm
# 0  005930       Y   삼성전자   삼성전자  20190515  20190515001605      분기보고서 (2019.03)
# 1  005930       Y   삼성전자   삼성전자  20190401  20190401004781   연  사업보고서 (2018.12)
# 2  005930       Y   삼성전자   삼성전자  20181114  20181114001530      분기보고서 (2018.09)
# 3  005930       Y   삼성전자   삼성전자  20180814  20180814001113      반기보고서 (2018.06)
# 4  005930       Y   삼성전자   삼성전자  20180515  20180515001699      분기보고서 (2018.03)

# %% [markdown]
# # <DART기업개황API사용>

# %%
##입력변수:  auth  ,  crp_cd
url_tmpl = 'http://dart.fss.or.kr/api/company.json?auth={auth}&crp_cd={code}'
url = url_tmpl.format(auth=auth, code='005930')
r = requests.get(url)
jo = json.loads(r.text) #딕셔너리 변환
jo
# Out:
# {'err_code': '000',
#  'err_msg': '정상',
#  'crp_nm': '삼성전자(주)',
#  'crp_nm_e': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'crp_nm_i': '삼성전자',
#  'stock_cd': '005930',
#  'ceo_nm': '김기남, 김현석, 고동진',
#  'crp_cls': 'Y',
#  'crp_no': '1301110006246',
#  'bsn_no': '1248100998',
#  'adr': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.sec.co.kr',
#  'ir_url': '',
#  'phn_no': '031-200-1114',
#  'fax_no': '031-200-7538',
#  'ind_cd': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %% [markdown]
# # <접수번호사용> 공시뷰어주소(url) 가져오기

# %%
# 데이터프레임 변환된 삼성전자 공시보고서(분기,반기,사업) 100건 데이터
result.head()
# Out:
#    crp_cd crp_cls crp_nm flr_nm    rcp_dt          rcp_no rmk           rpt_nm
# 0  005930       Y   삼성전자   삼성전자  20190515  20190515001605      분기보고서 (2019.03)
# 1  005930       Y   삼성전자   삼성전자  20190401  20190401004781   연  사업보고서 (2018.12)
# 2  005930       Y   삼성전자   삼성전자  20181114  20181114001530      분기보고서 (2018.09)
# 3  005930       Y   삼성전자   삼성전자  20180814  20180814001113      반기보고서 (2018.06)
# 4  005930       Y   삼성전자   삼성전자  20180515  20180515001699      분기보고서 (2018.03)

# %%
# rcp_no : 접수번호 <- 문서의 고유번호

## 20190515001605 은 삼성전자 분기보고서 (2019.03)의 접수번호.

result.head(1)


## 접수번호(공시뷰어 연결에 이용) - PC용 : http://dart.fss.or.kr/dsaf001/main.do?rcpNo=접수번호
# Out:
#    crp_cd crp_cls crp_nm flr_nm    rcp_dt          rcp_no rmk           rpt_nm
# 0  005930       Y   삼성전자   삼성전자  20190515  20190515001605      분기보고서 (2019.03)

# %%
# 접수번호를 사용하여 공시뷰어주소(url) 출력
## 공시뷰어 주소형식 ->  http://dart.fss.or.kr/dsaf001/main.do?rcpNo={}



## result : 데이터프레임 변환된 삼성전자 공시보고서(분기,반기,사업) 최근 100건 데이터 (데이터프레임)
df = result[:10] # 처음 10개 데이터만 가져오기


## 삼성전자 최근 보고서 페이지주소 출력
for ix, row in df.iterrows():
    url_tmpl = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo={}"
    url = url_tmpl.format(row['rcp_no']) 
    print (ix, url)
# Out:
# 0 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20190515001605
# 1 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20190401004781
# 2 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20181114001530
# 3 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20180814001113
# 4 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20180515001699
# 5 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20180402005019
# 6 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20171114001694
# 7 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20170814001832
# 8 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20170515003806
# 9 http://dart.fss.or.kr/dsaf002/main.do?rcpNo=20170331004518

# %% [markdown]
# # <공시뷰어url 사용>  공시보고서 내용 스크래핑/파싱

# %%
# 웹페이지 스크래핑

import requests
from bs4 import BeautifulSoup


r = requests.get('http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20190401004781') 

# print(r.text) # 페이지의 HTML 소스코드
## 보고서가 여러 페이지로 구성되어 있음

# %% [markdown]
# # <공시뷰어url 사용>  하위 보고서 내용 스크래핑/파싱

# %%
# 하위보고서(페이지) 별 공시뷰어 주소(url) 추출하기 [하위보고서가 여러개인 경우]



##보고서 페이지의  HTML 소스코드상에서 하위보고서(페이지) 간의 일치하는 패턴을 파악.



##  "{viewDoc\('(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\S+)'\)\;"




## 패턴들에서 데이터를 추출하여 링크로 구성
import requests
import re

r = requests.get('http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20190401004781')

matches = re.findall("{viewDoc\('(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\S+)'\)\;", r.text)


#len(matches) # 하위보고서(페이지)의 개수

m = matches[0]
m


doc_url_tmpl = "http://dart.fss.or.kr/report/viewer.do?rcpNo=%s&dcmNo=%s&eleId=%s&offset=%s&length=%s&dtd=%s" 
subpage_url = doc_url_tmpl % m
subpage_url
# Out:
# 'http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=1&offset=793&length=4059&dtd=dart3.xsd'

# %%
# 하위보고서(페이지) 별 공시뷰어 주소(url) 추출하기 [하위보고서가 1개인 경우]

##페이지의 구성에 차이가 있기 때문위 위와 동일한 정규식으로 매칭이 되지않음.


##새로운 정규식 패턴을 찾아야됨.
#ex) 한진중공업 홀딩스, [정정] 주요사항보고서(감자결정) http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20190329803953


r = requests.get('http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20190329803953')

matches = re.findall("\t\tviewDoc\('(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\S+)'\)\;", r.text)
matches
# Out:
# [('20190329803953', '6595634', '0', '0', '0', 'HTML')]

# %%
import json
import re
import urllib
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
from pandas.io.json import json_normalize

def sub_report_urls(rcp_no):
    '''
    접수번호(rcp_no)에 해당하는 모든 하위 보고서 URL을 추출하여 리스트로 반환
    '''
    doc_urls = []
    url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=%s" % (rcp_no)
    r = requests.get(url)

    multi_page_re = "{viewDoc\('(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\S+)'\)\;"
    single_page_re = "\t\tviewDoc\('(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\S+)'\)\;"

    matches = re.findall(multi_page_re, r.text)
    if len(matches) == 0: 
        matches = re.findall(single_page_re, r.text)

    doc_url_tmpl = "http://dart.fss.or.kr/report/viewer.do?rcpNo=%s&dcmNo=%s&eleId=%s&offset=%s&length=%s&dtd=%s" 
    for m in matches:
        url = doc_url_tmpl % m
        doc_urls.append(url)
    return doc_urls


def sub_report_titles(rcp_no):
    '''
    접수번호(rcp_no)에 해당하는 모든 하위 보고서의 제목 리스트 반환
    '''
    url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=%s" % (rcp_no)
    r = requests.get(url)
    matches = re.findall('text: \"(.*)\",', r.text)

    doc_titles = matches[1:] # '전체' 제외
    if len(doc_titles) == 0: # 1페이지 경우 (본문의 첫 라인)
        title = BeautifulSoup(r.text).title.text.strip()
        doc_titles = [title]

    return doc_titles

# %%
# 사업 보고서 하위 문서 전체

doc_urls = sub_report_urls('20190401004781')

print('하위보고서 갯수:', len(doc_urls))

for url in doc_urls:
    print (url)
# Out:
# 하위보고서 갯수: 33
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=1&offset=793&length=4059&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=2&offset=12878&length=418&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=3&offset=13300&length=314299&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=4&offset=13390&length=212568&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=5&offset=225962&length=17460&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=6&offset=243426&length=3817&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=7&offset=247247&length=63793&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=8&offset=311044&length=7390&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=9&offset=318438&length=9147&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=10&offset=327603&length=276012&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=11&offset=603619&length=1499098&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=12&offset=603746&length=21585&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=13&offset=625579&length=120141&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=14&offset=745724&length=586931&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=15&offset=1332659&length=90711&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=16&offset=1423374&length=476461&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=17&offset=1899865&length=202838&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=18&offset=2102721&length=71625&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=19&offset=2174350&length=15062&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=20&offset=2189416&length=122835&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=21&offset=2189529&length=95322&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=22&offset=2284855&length=26556&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=23&offset=2311415&length=822&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=24&offset=2312255&length=60584&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=25&offset=2372843&length=860722&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=26&offset=2372955&length=797499&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=27&offset=3170458&length=63093&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=28&offset=3233569&length=508460&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=29&offset=3742033&length=59316&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=30&offset=3801353&length=73917&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=31&offset=3875274&length=346&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=32&offset=3875375&length=112&dtd=dart3.xsd
# http://dart.fss.or.kr/report/viewer.do?rcpNo=20190401004781&dcmNo=6616741&eleId=33&offset=3875491&length=115&dtd=dart3.xsd

# %%
## 삼성전자 최근 보고서 페이지주소 출력
for ix, row in df.iterrows():
    
    doc_urls = sub_report_urls(row['rcp_no'])

    print('하위보고서 갯수:', len(doc_urls))
# Out:
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33
# 하위보고서 갯수: 33

# %% [markdown]
# ---
# < 용어정리 >
#
# * 크롤링(crawling)
#
# 크롤링이란 단어는 웹 크롤러(crawler)라는 단어에서 시작한 말이다.
#
# 크롤러란 조직적, 자동화된 방법으로 월드와이드 웹을 탐색하는 컴퓨터 프로그램이다.(출처: 위키백과)
#
# 크롤링은 크롤러가 하는 작업을 부르는 말로, 여러 인터넷 사이트의 페이지(문서, html 등)를 수집해서 분류하는 것이다.
#
# 대체로 찾아낸 데이터를 저장한 후 쉽게 찾을 수 있게 인덱싱한다.<br><br>
#
#
#
# * 파싱(parsing)
#
# 파싱이란 어떤 페이지(문서, html 등)에서 내가 원하는 데이터를 특정 패턴이나 순서로 추출하여 정보를 가공하는 것이다.
#
# 위 문장만 보면 굉장히 간단해 보이지만 컴퓨터 과학적 정의를 보면 파싱이란 일련의 문자열을 의미있는 토큰(token)으로 분해하고 이들로 이루어진 파스 트리(parse tree)를 만드는 과정을 말한다.(출처: 위키백과)
#
# 인터프리터나 컴파일러의 구성 요소 가운데 하나로, 입력 토큰에 내제된 자료 구조를 빌드하고 문법을 검사하는 역할을 한다.<br><br>
#
#
#
# * 스크래핑(scraping)
#
# 스크래핑이란 HTTP를 통해 웹 사이트의 내용을 긁어다 원하는 형태로 가공하는 것이다.
#
# 쉽게 말해 웹 사이트의 데이터를 수집하는 모든 작업을 뜻한다.
#
# 크롤링도 일종의 스크래핑 기술이라고 할 수 있다.
#
#
#
# <br><br>
# 참고사이트: https://aftersiesta.tistory.com/8
#
# ---
#
# <br><br>

# %%
import requests
import re

for ix, row in df.iterrows():
    url_tmpl = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo={}"
    url = url_tmpl.format(row['rcp_no'])

    r = requests.get(url)
#     print(r.text)
    matches = re.findall("{viewDoc\('(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\d+)', '(\S+)'\)\;", r.text)
    m = matches[0]
    print(m)
# Out:
# ('20190515001605', '6738798', '1', '670', '4104', 'dart3.xsd')
# ('20190401004781', '6616741', '1', '793', '4059', 'dart3.xsd')
# ('20181114001530', '6382016', '1', '575', '4053', 'dart3.xsd')
# ('20180814001113', '6282263', '1', '575', '4058', 'dart3.xsd')
# ('20180515001699', '6180129', '1', '564', '4104', 'dart3.xsd')
# ('20180402005019', '6060273', '1', '712', '4052', 'dart3.xsd')
# ('20171114001694', '5845320', '1', '564', '4139', 'dart3.xsd')
# ('20170814001832', '5752868', '1', '564', '4055', 'dart3.xsd')
# ('20170515003806', '5653406', '1', '564', '4104', 'dart3.xsd')
# ('20170331004518', '5540271', '1', '712', '4053', 'dart3.xsd')

# %%
soup = BeautifulSoup(r.text, 'html.parser') #객체 생성 (파싱할 문서를 BeautifulSoup 클래스의 생성자에 넘겨주어 문서 개체를 생성)

# print(soup) 
print(soup.prettify()) # 보기 편하게 출력

# %% [markdown]
# <br><br>
#
# # 첨부파일 다운로드

# %%
import os
import re
import requests

pdf_link_tmpl = "http://dart.fss.or.kr/pdf/download/pdf.do?rcp_no={rcp_no}&dcm_no={dcm_no}"
excel_link_tmpl = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no={rcp_no}&dcm_no={dcm_no}&lang=ko"
ifrs_link_tmpl = "http://dart.fss.or.kr/pdf/download/ifrs.do?rcp_no={rcp_no}&dcm_no={dcm_no}&lang=ko"




# 입력값 : 접수번호(문서의 고유번호)

def get_report_attach_urls(rcp_no):
    attach_urls = []

    url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=%s" % (rcp_no)
    r = requests.get(url)

    start_str = "javascript: viewDoc\('" + rcp_no + "', '"
    end_str = "', null, null, null,"
    reg = re.compile(start_str + '(.*)' + end_str)
    m = reg.findall(r.text)
    dcm_no = m[0]
    
    attach_urls.append(pdf_link_tmpl.format(rcp_no=rcp_no, dcm_no= dcm_no))
    attach_urls.append(excel_link_tmpl.format(rcp_no=rcp_no, dcm_no= dcm_no))
    attach_urls.append(ifrs_link_tmpl.format(rcp_no=rcp_no, dcm_no= dcm_no))
    return attach_urls

# %%
# http://dart.fss.or.kr/dsaf001/main.do?rcpNo=20170515003806

# 2017년 3월 삼성전자 분기보고서

rcp_no = '20170515003806'
attach_urls = get_report_attach_urls(rcp_no)
attach_urls
# Out:
# ['http://dart.fss.or.kr/pdf/download/pdf.do?rcp_no=20170515003806&dcm_no=5653406',
#  'http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20170515003806&dcm_no=5653406&lang=ko',
#  'http://dart.fss.or.kr/pdf/download/ifrs.do?rcp_no=20170515003806&dcm_no=5653406&lang=ko']

# %%
## 
import json
from pandas.io.json import json_normalize 

# 회사의 전체 사업+반기+분기보고서 100건

url_tmpl = 'http://dart.fss.or.kr/api/search.json?auth={auth}&crp_cd={code}&start_dt=19990101&bsn_tp=A001&bsn_tp=A002&bsn_tp=A003&page_set=100'


url = url_tmpl.format(auth=auth, code ='005930' )
r = requests.get(url)
jo = json.loads(r.text)
result = json_normalize(jo, 'list')


result2 = result.head()[['crp_cd','rpt_nm','rcp_no']]

# result2

for ix,row in result2.iterrows():
    print('start@@@')
    attach_urls = get_report_attach_urls(row[2])
    print(attach_urls[1])
# Out:
# start@@@
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20190515001605&dcm_no=6738798&lang=ko
# start@@@
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20190401004781&dcm_no=6616741&lang=ko
# start@@@
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20181114001530&dcm_no=6382016&lang=ko
# start@@@
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20180814001113&dcm_no=6282263&lang=ko
# start@@@
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20180515001699&dcm_no=6180129&lang=ko

# %%
# 보고서 PDF 문서
requests.get(url).content
# url = attach_urls[0]
# fname = '005930_' + rcp_no + '.pdf'

# with open(fname, 'wb') as f:
#     f.write(requests.get(url).content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b4b97a511887> in <module>
#       1
#       2 # 보고서 PDF 문서
# ----> 3 requests.get(url).content
#       4 # url = attach_urls[0]
#       5 # fname = '005930_' + rcp_no + '.pdf'
#
# NameError: name 'url' is not defined

# %%
# ls -al 005930*
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 38C6-CD58
#
#  C:\jupyter_project\git_office 디렉터리
#
#
#  C:\jupyter_project\git_office 디렉터리
#
# 2019-07-25  오전 10:50         1,596,666 005930_20170515003806.pdf
#                1개 파일           1,596,666 바이트
#                0개 디렉터리  164,378,075,136 바이트 남음

# %%
#재무제표 직접읽기
import pandas as pd
from openpyxl import load_workbook
from urllib.request import urlopen





url = 'http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20170515003806&dcm_no=5653406&lang=ko'



# xls = pd.ExcelFile(url)
# sheet_names = xls.sheet_names

# for i in sheet_names:
    

#     df = pd.read_excel(url, sheet_name=i, index_col=0, skiprows=7)
#     print("$$$$$")
#     print(i)
#     print(df.head())

df = pd.read_excel(url, sheet_name='재무상태표', index_col=0, skiprows=7)
df


df1 = pd.read_excel(url, sheet_name='연결 재무상태표', index_col=0 ,skiprows=6)
df1


import pandas as pd

file_name = row['종목명']+row['접수번호']

writer = pd.ExcelWriter('C:/Users/KICPA/Desktop/DART_IFRS 택사노미 대조작업/택사노미집계자동화작업.xlsx')

df_IFRS19_roll.to_excel(writer, sheet_name='IFRS19',header=True)



# 
# load_wb = load_workbook(url,data_only = True)


# sheet_lit = load_wb.get_sheet_names()
# sheet_lit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-cfd6c492554f> in <module>
#      29 df1 = pd.read_excel(url, sheet_name='연결 재무상태표', index_col=0 ,skiprows=6)
#      30 df1
# ---> 31 pwd
#      32 # load_wb = load_workbook(url,data_only = True)
#      33
#
# NameError: name 'pwd' is not defined

# %%
from urllib.request import urlopen
from openpyxl import load_workbook

try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    
    
data = urlopen('http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20170515003806&dcm_no=5653406&lang=ko')
xlsx = data.read()
wb = load_workbook(StringIO.StringIO(xlsx))
load_wb.get_sheet_names()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-605ad5e726c6> in <module>
#      10 data = urlopen('http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20170515003806&dcm_no=5653406&lang=ko')
#      11 xlsx = data.read()
# ---> 12 wb = load_workbook(StringIO(xlsx))
#      13 load_wb.get_sheet_names()
#
# TypeError: initial_value must be str or None, not bytes

# %% [markdown]
# <br>
#
# # 최근 분기보고서(1,2,3,4분기보고서)를 업로드한 기업의 엑셀파일 자동 다운로드

# %%
os.path.dirname(os.path.abspath('C:\DATA'))
# Out:
# 'C:\\'

# %% [markdown]
# <br><br>
#
# # 최근 공시 페이지 스크래핑/파싱

# %%
################################################
import json
from pandas.io.json import json_normalize
import requests
from bs4 import BeautifulSoup
################################################
# 실제 인증키를 사용
auth = '' 


# 최근 공시페이지 스크래핑





## 하지만 최근 공시 전체 페이지에 누락된 보고서도 존재하므로  검색API 접수문서 리스트를 사용하는 것이 바람직하다.

req = requests.get('http://dart.fss.or.kr/dsac001/mainAll.do')
req.encoding = 'utf-8' 

html = req.text
soup = BeautifulSoup(html, 'html.parser')
test = soup.find('div',{'class':'table_list'})
test1 =test.find_all('tr')

test_corp=[]
for i in test1[1:]:
    
    time = i.find_all('td',{'class':'cen_txt'})[0].text.split()[0]
    corp_name = i.find_all('a')[0].text.split()[0]
    report_name = i.find_all('a')[1].text.split()[0]
    submitter = i.find('div',{'class':'nobr'}).text.split()[0]
    submit_day = i.find_all('td',{'class':'cen_txt'})[1].text.split()[0]

    
    latest = time +'/'+corp_name+'/'+report_name+'/'+submitter+'/'+submit_day
    print(latest)
# Out:
# 10:42/미래에셋대우/투자설명서(일괄신고)/미래에셋대우/2019.07.26
# 10:38/한국투자증권/투자설명서(일괄신고)/한국투자증권/2019.07.26
# 10:36/청원건설산업/[기재정정]특수관계인으로부터자금차입/청원건설산업/2019.07.26
# 10:35/케이비증권/일괄신고추가서류(파생결합증권-주가연계증권)/케이비증권/2019.07.26
# 10:34/미래에셋대우/투자설명서(일괄신고)/미래에셋대우/2019.07.26
# 10:34/중흥토건/특수관계인으로부터자금차입/중흥토건/2019.07.26
# 10:33/재영솔루텍/연결재무제표기준영업(잠정)실적(공정공시)/재영솔루텍/2019.07.26
# 10:33/오이솔루션/단일판매ㆍ공급계약체결/오이솔루션/2019.07.26
# 10:32/중봉산업개발/특수관계인에대한자금대여/중봉산업개발/2019.07.26
# 10:31/한국투자증권/일괄신고추가서류(파생결합증권-주가연계증권)/한국투자증권/2019.07.26
# 10:30/중흥토건/특수관계인으로부터자금차입/중흥토건/2019.07.26
# 10:29/미래에셋대우/일괄신고추가서류(기타파생결합증권)/미래에셋대우/2019.07.26
# 10:29/순천에코밸리/특수관계인에대한자금대여/순천에코밸리/2019.07.26
# 10:27/세종중흥건설/특수관계인으로부터자금차입/세종중흥건설/2019.07.26
# 10:26/이랜드크루즈/특수관계인으로부터자금차입/이랜드크루즈/2019.07.26
# 10:25/영담/특수관계인으로부터자금차입/영담/2019.07.26
# 10:24/미래에셋대우/투자설명서(일괄신고)/미래에셋대우/2019.07.26
# 10:23/청원건설산업/특수관계인으로부터자금차입/청원건설산업/2019.07.26
# 10:23/자이에스앤디/타인에대한채무보증결정/자이에스앤디/2019.07.26
# 10:22/미래에셋대우/일괄신고추가서류(파생결합증권-주가연계증권)/미래에셋대우/2019.07.26
# 10:16/신보2018제6차유동화전문유한회사/사업보고서(유동화전문회사)/신보2018제6차유동화전문유한회사/2019.07.26
# 10:16/한국주택금융공사/[변경등록]채권유동화계획의등록신청서[한국주택금융공사]/한국주택금융공사/2019.07.25
# 10:16/한국주택금융공사/채권유동화계획의등록신청서[한국주택금융공사]/한국주택금융공사/2019.07.11
# 10:11/신보2015제2차유동화전문유한회사/사업보고서(유동화전문회사)/신보2015제2차유동화전문유한회사/2019.07.26
# 10:10/삼성증권/증권발행실적보고서/삼성증권/2019.07.26
# 10:10/셀트리온충북대코스메틱스/임원의변동/셀트리온충북대코스메틱스/2019.07.26
# 10:10/NH투자증권/증권발행실적보고서/NH투자증권/2019.07.26
# 10:09/NH투자증권/연결재무제표기준영업(잠정)실적(공정공시)/NH투자증권/2019.07.26
# 10:08/에이프로젠제약/유상증자또는주식관련사채등의청약결과(자율공시)/에이프로젠제약/2019.07.26
# 10:08/삼성증권/증권발행실적보고서/삼성증권/2019.07.26
# 10:07/SK텔레콤/기업설명회(IR)개최(안내공시)/SK텔레콤/2019.07.26
# 10:01/미래에셋대우/투자설명서(일괄신고)/미래에셋대우/2019.07.26
# 09:51/미래에셋대우/일괄신고추가서류(기타파생결합증권)/미래에셋대우/2019.07.26
# 09:50/마포애경타운/임원의변동/마포애경타운/2019.07.26
# 09:50/미래에셋대우/일괄신고추가서류(파생결합증권-주가연계증권)/미래에셋대우/2019.07.26
# 09:46/경남기업/특수관계인에대한자금대여/경남기업/2019.07.26
# 09:43/신보2016제5차유동화전문유한회사/사업보고서(유동화전문회사)/신보2016제5차유동화전문유한회사/2019.07.26
# 09:42/신보2016제9차유동화전문유한회사/사업보고서(유동화전문회사)/신보2016제9차유동화전문유한회사/2019.07.26
# 09:28/삼성증권/투자설명서(일괄신고)/삼성증권/2019.07.26
# 09:24/케이티스카이라이프/영업(잠정)실적(공정공시)/케이티스카이라이프/2019.07.26
# 09:24/삼성증권/투자설명서(일괄신고)/삼성증권/2019.07.26
# 09:24/케이티스카이라이프/연결재무제표기준영업(잠정)실적(공정공시)/케이티스카이라이프/2019.07.26
# 09:15/금호티앤엘/특수관계인으로부터부동산임차/금호티앤엘/2019.07.26
# 09:15/푸르덴셜파이낸셜인크/투자설명서/푸르덴셜파이낸셜인크/2019.07.26
# 09:14/삼성증권/일괄신고추가서류(파생결합사채-주가연계파생결합사채)/삼성증권/2019.07.26
# 09:13/삼성증권/일괄신고추가서류(파생결합증권-주가연계증권)/삼성증권/2019.07.26
# 09:11/금호티앤엘/동일인등출자계열회사와의상품ㆍ용역거래변경/금호티앤엘/2019.07.26
# 09:09/한국투자캐피탈/투자설명서(일괄신고)/한국투자캐피탈/2019.07.26
# 09:08/S&T홀딩스/연결재무제표기준영업(잠정)실적(공정공시)/S&T홀딩스/2019.07.26
# 09:04/신한지주/투자설명서(일괄신고)/신한지주/2019.07.26
# 09:02/한국투자캐피탈/일괄신고추가서류/한국투자캐피탈/2019.07.26
# 09:02/산은캐피탈/투자설명서(일괄신고)/산은캐피탈/2019.07.26
# 09:01/S&TC/연결재무제표기준영업(잠정)실적(공정공시)/S&TC/2019.07.26
# 09:01/신한지주/일괄신고추가서류/신한지주/2019.07.26
# 09:01/S&T중공업/연결재무제표기준영업(잠정)실적(공정공시)/S&T중공업/2019.07.26
# 09:01/S&T모티브/연결재무제표기준영업(잠정)실적(공정공시)/S&T모티브/2019.07.26
# 09:00/산은캐피탈/일괄신고추가서류/산은캐피탈/2019.07.26
# 08:57/IBKS제9호스팩/[기재정정]참고서류/IBKS제9호스팩/2019.07.26
# 08:25/아이엘사이언스/주권매매거래정지/코넥스시장/2019.07.26
# 08:25/신영스팩4호/주권매매거래정지/코스닥시장본부/2019.07.26
# 08:25/아이엘사이언스/주요사항보고서(회사합병결정)/아이엘사이언스/2019.07.26
# 08:25/신영스팩4호/주요사항보고서(회사합병결정)/신영스팩4호/2019.07.26
# 07:37/삼광글라스/연결재무제표기준영업(잠정)실적(공정공시)/삼광글라스/2019.07.26
# 07:30/평화홀딩스/[기재정정]주요사항보고서(유상증자결정)(자회사의/평화홀딩스/2019.07.26
# 07:30/푸르덴셜파이낸셜인크/효력발생안내/금융감독원/2019.07.26
# 07:30/평화산업/[기재정정]주요사항보고서(유상증자결정)/평화산업/2019.07.26
# 07:30/평화산업/[발행조건확정]증권신고서(지분증권)/평화산업/2019.07.26
# 07:30/평화산업/[기재정정]투자설명서/평화산업/2019.07.26

# %% [markdown]
# <br><br>
#
# # 검색API사용. 최근 공시보고서 텔레그램 메시지 자동알림

# %%
###########################################
import requests
from bs4 import BeautifulSoup
import os
import time
import telegram
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize
##########################################
# 실제 인증키를 사용
auth = '' 




# 최근 공시보고서 텔레그램 메시지 자동 알림



# key
API_TOKEN = ''
chat_id = ""

#텔레그램 봇
bot = telegram.Bot(token=API_TOKEN)

#text파일
# f = open("C:\\DATA\\latest.txt", 'w')
# f.close()

#switch
switch = False


#텍스트 파일의 위치
# BASE_DIR = os.path.abspath('C:\DATA')







def mapping_func(data,col_name):
    
    #기타 정보 상세화
    
    corp_type = {'Y':'유가증권시장',
            'K':'코스닥',
            'N':'코넥스',
            'E':'기타'}


    dept ={ '유':'KRX 코스닥시장본부 소관',
            '코':'KRX 코스닥시장본부 소관',
            '채':'KRX 채권상장법인 공시사항',
            '넥':'KRX 코넥스시장 소관',
            '공':'공정거래위원회 소관',
            '연':'연결부분포함',
            '정':'제출후정정신고존재',
            '철':'철회(간주)'}
    
    
    
    #해당 정보추출작업
    
    if col_name == '법인구분' or    col_name == '비고':    
    
        try:           
            
            if col_name == '법인구분':
            
                return corp_type[data[col_name].values[0]]
    
    
            else:

                return dept[data[col_name].values[0]]
        
        
        except: # col_name 이 없는 경우
            
            return ''
                
                
    else:
        
        return data[col_name].values[0]
        
 




        
#automation

while True:
    
    
    url_tmpl = 'http://dart.fss.or.kr/api/search.json?auth={auth}'
    url = url_tmpl.format(auth=auth)
    r = requests.get(url)
    jo = json.loads(r.text)
    result = json_normalize(jo, 'list')
    

    cols = {'crp_cd':'종목코드','crp_cls':'법인구분','crp_nm':'종목명','flr_nm':'제출인',
        'rcp_dt':'접수날짜','rcp_no':'접수번호','rmk':'비고','rpt_nm':'보고서명'}
    
    result.rename(columns=cols, inplace=True)
    
    
    
    
    if switch == False:
        
        
        
        recent_disc =[]
        recent_disc.append(result['접수번호'][0])
        before = recent_disc[0]             
        
        new_disc = result.loc[result['접수번호'] == before,:]
        

        link = 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=' + before
        chat_text = "[%s] %s \n %s \n %s \n %s" % ( mapping_func(new_disc,'종목명'),mapping_func(new_disc,'법인구분'),
                                                    mapping_func(new_disc,'보고서명'),mapping_func(new_disc,'비고'),link )

        url_tmpl = "https://api.telegram.org/bot%s/sendMessage?chat_id=%s&text=%s"
        url =  url_tmpl % (API_TOKEN, chat_id, chat_text)


        r = requests.get(url)

        
        switch =True
    
    
    
    
    
    
    else:
        
        
        
        recent_disc =  list(result['접수번호'])

        recent_disc_arr = np.array(recent_disc)
        latest = recent_disc_arr[0]
           

            

        if before != latest:   #error
            
            
            idx = np.where(recent_disc_arr == before)[0][0]
            

            
            for i in recent_disc_arr[:idx][::-1]:
                

                new_disc = result.loc[result['접수번호'] == i,:]
                
                
                
                link = 'http://dart.fss.or.kr/dsaf001/main.do?rcpNo=' + i
                chat_text = "[%s] %s \n %s \n %s \n %s" % ( mapping_func(new_disc,'종목명'),mapping_func(new_disc,'법인구분'),
                                                            mapping_func(new_disc,'보고서명'),mapping_func(new_disc,'비고'),link )
                
                url_tmpl = "https://api.telegram.org/bot%s/sendMessage?chat_id=%s&text=%s"
                url =  url_tmpl % (API_TOKEN, chat_id, chat_text)


                r = requests.get(url)



        #테스트 목적
        else:
            
            
            bot.sendMessage(chat_id=chat_id , text='새로운 공시가 없습니다.')   


            
        
        
        before = latest
        
        
       
    
    
    
    
        
    time.sleep(60)

# %%
import requests
from pandas.io.json import json_normalize 
import json
####
import requests
from bs4 import BeautifulSoup
import os
import time
import telegram
import numpy as np


# 실제 인증키를 사용
auth = '' 

url_tmpl = 'http://dart.fss.or.kr/api/search.json?auth={auth}'
# url_tmpl = 'http://dart.fss.or.kr/api/search.json?auth={auth}&crp_cls'
url = url_tmpl.format(auth=auth)
r = requests.get(url)
jo = json.loads(r.text)
result = json_normalize(jo, 'list')



# new_disc = result.loc[result['rcp_no'] == '20190726000264',:]
# new_disc
# Out:
#    crp_cd crp_cls crp_nm flr_nm    rcp_dt          rcp_no rmk     rpt_nm
# 0  016360       Y   삼성증권   삼성증권  20190726  20190726000264      증권발행실적보고서

# %% [markdown]
# <br><br>
#
# # 최근 공시보고서 여러명에게 텔레그램 알림하기

# %% [markdown]
# <br><br>
#
# # 관심기업의 최근 공시보고서 텔레그램 알림

# %% [markdown]
# <br><br>
#
# # 텔레그램 메시지 받기 ( telegram 모듈을 사용하여)

# %%
#  telegram의 Bot() 메서드 사용 X
#         url_tmpl = "https://api.telegram.org/bot%s/sendMessage?chat_id=%s&text=%s"
#        url =  url_tmpl % (API_TOKEN, chat_id, chat_text)
#       r = requests.get(url)



import telegram 


# my_token = ''   

#  telegram의 Bot() 메서드 사용 O
bot = telegram.Bot(token = my_token)   #bot을 선언합니다.
updates = bot.getUpdates()  #업데이트 내역을 받아옵니다.



# for u in updates :   # 내역중 메세지를 출력합니다.

#     print(u.message)



chat_id = bot.getUpdates()[-1].message.chat.id

print(chat_id)

bot.sendMessage(chat_id = chat_id, text="저는 봇입니다.")
# Out:
# 868118183

# %% [markdown]
# <br><br>
#
# # 채널 생성

# %% [markdown]
# **계정** : 하나의 주체<br>
# 사용자 혹은 bot등이 여기 해당됨<br> <br>
#
# **채널** : 열린 채팅방<br>
#
# 그룹이 단순히 여러명이 모여 대화를 나누는 곳이라면 여기에는 그 이상의 기능이 가능.
# 채널을 공개하여 여러 사람이 들어올 수도 있으며(지진희알림등) 관리자등을 지정하고 이들만 채팅이 가능하도록 하는 등 알림용도로도 사용이 가능

# %%
import telegram

# my_token = ''

bot = telegram.Bot(token = my_token) #봇을 생성합니다.

id_channel = bot.sendMessage(chat_id='@clients_chatting', text="I'm robot").chat_id



# bot.sendMessage(chat_id=id_channel, text="I'm bot") #@bill_chat 으로 메세지를 보냅니다.

# %%
from telegram.ext import Updater, MessageHandler, Filters  # import modules

# my_token = ''

# print('start telegram chat bot')


# message reply function
def get_message(bot, update) :
    update.message.reply_text("got text")
    update.message.reply_text(update.message.text)
    

updater = Updater(my_token)

message_handler = MessageHandler(Filters.text, get_message)
updater.dispatcher.add_handler(message_handler)

updater.start_polling(timeout=3, clean=True)
print(updater.idle())
