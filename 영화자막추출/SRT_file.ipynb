# %%
import re

text = '00:04:18'

stime_pattern = re.compile('(\d{2}:\d{2}:\d{2},)')

if stime_pattern.match(text) is None:
    print(text)
# Out:
# 00:04:18

# %%
import os
import re
import glob






def make_file(f_in,input_file_name,path):
    
    global clear_dir
    global error_lst
    
#     new_path =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text'
    new_path =r'C:\Users\CHS\Desktop\wcoding\data'

#     output_file_name = re.sub('[^a-z|A-Z|0-9|가-힣|\u4E00-\u9FFF|\u3040-\u309Fー|\u30A0-\u30FF|\\\]','' ,input_file_name ) 

#     end_num = re.search('20..|19..',output_file_name)

#     output_file_name =output_file_name[:end_num.regs[0][0]]

#     start_num2 = output_file_name.rfind('\\')        

#     output_file_name = path + output_file_name[start_num2:]+'.txt'
    

    start_num = input_file_name.rfind('\\')
    output_file_name = input_file_name[start_num:-4]
    output_file_name = new_path + output_file_name + '.txt'
    

    if input_file_name.endswith('.srt'):
        f_out = open(output_file_name, 'w',encoding='utf-8-sig')
    else :
        f_out = open(output_file_name, 'w')
        
        

    lines = filter(None, (line.strip() for line in f_in) )
    

    seq_num = 1       
        
#     trigger = True

#     none_number = 0
    
    
    for line in lines:   
    
        print(line)
        print(line[0])
        try:
            
 
            if int(line) < 9999:

                if int(line) == 1:
                    seq_num = seq_num +1   #2
                    print("finallll:",seq_num)

                if int(line) != seq_num:    #1 != 2                   
                    pass

                else :
                    f_out.write('\n')  
                    seq_num = seq_num + 1   # 3


            else:

                line = line + ' '
                f_out.write(line)                   

                

        except:
            
            start_word=('자막','제공','제작','SUB','{','#','++',
                '번역','\"넷플릭스','최종수정','HTTP','SRT','수입','배급',
                '영상정보','제목','\"NETFLIX','SMI','IRATEMOTOR','SUBTITLE','제목',' ')

            stime_pattern = re.compile('(\d{2}:\d{2}:\d{2},)')     
        
            
            word = ['♪','<>','--','-','</>','¿','¡','#','/','♬']
                

                
            if  line.upper().startswith(start_word):
                continue


            if stime_pattern.match(line) is not None:
                continue
             


            for i in re.findall(r"<(.+?)>", line):

                line = re.sub(i,'',line)


            for w in word:
                line = re.sub(w,'',line)   


            line = line + ' '
            f_out.write(line)
    

    
#             if re.search('([가-힣]{2}.+)',line) is not None:
#                 none_number = none_number + 1               

            
                
    f_out.close()      
    

#     if none_number < 100:

#         trigger = False
        

#     if trigger == False:

# #         clear_dir.append(output_file_name)
#         os.reduce(output_file_name)
#         print('삭제: ', output_file_name)
    


                




    
    
def encoding_func(input_file_name, path):
    
    global clear_dir
    global error_lst
    
    try:
        with open(input_file_name) as f_in:
            make_file(f_in,input_file_name,path)
            print('@@')
            
    except:
        
        try:
            with open(input_file_name,encoding='utf-8-sig') as f_in:
                make_file(f_in,input_file_name,path)
                
        except:                     

            try:
                with open(input_file_name,encoding='latin1-sig') as f_in:
                    make_file(f_in,input_file_name,path)

            except:
                print('\n[error]',input_file_name,'\n')
                
                error_lst.append(input_file_name)


            
    f_in.close()
    


def main():
    
    global error_lst
    global clear_dir
    
    
    
    p =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2'### 경로 설정해줄 것.
    new_path =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text'
    
#     for(path, dir, files) in os.walk(p):
# #         subtitle_list = glob.glob(path+'\\*.smi')
# #         subtitle_list.extend(glob.glob(path+'\\*.srt'))
    
#         subtitle_list = glob.glob(path+'\\*.srt')
    
    
#     lang_word =('eng.srt','esp.srt','en.srt','english.srt','eng.srt')
    

#     for file_name in subtitle_list:
                      
#         if file_name.lower().endswith(lang_word):

#             continue      
       
#         if re.search(r'(영어.+|eng)',file_name.lower()) is not None:
            
#             continue

            
            
#         if re.search(r'(\[영어.+\]|\[eng.+\])',file_name.lower()) is not None:
#              print('@@')
#             continue



#         error_t=encoding_func(file_name,p)
            
        

        
#     testt =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\a.prayer.before.dawn.2017.1080p.amzn.web-dl.ddp5.1.h.264-ntg.eng.srt' 
#     testt =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\[Shiniori-Raws]+009+Re+Cyborg+The+Movie+BD+1280x720+x264+AAC.srt'
#     error_t = encoding_func( testt , p )  
    testt =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\[Discovery2006_0503]+The+Battle+Of+Chernobyl.srt'
    error_t = encoding_func( testt , p )
    
    
    
error_lst=[]
clear_dir=[]

if __name__ == '__main__':
    main()
# Out:
# 1
# 1
# finallll: 2
# 00:00:07,870 --> 00:00:13,930
# 0
# 1986년, 4월 25일 금요일
# 1
# 2
# 2
# 00:00:14,740 --> 00:00:15,800
# 0
# 아름다운 봄날
# 아
# 3
# 3
# 00:00:16,040 --> 00:00:19,780
# 0
# 우크라이나의 도시,
# 우
# 프리피야트의 43,000명의 거주자들
# 프
# 4
# 4
# 00:00:21,320 --> 00:00:24,770
# 0
# 그들의 기억에 영원히 새겨질 날.
# 그
# 00:00:26,000 --> 00:00:35,530
# 0
# -Discovery channel-
# -
# 2006년 5월(사고 20년후) 방영.
# 2
# 5
# 5
# 00:00:38,070 --> 00:00:39,530
# 0
# 그 시로부터 3km,
# 그
# 6
# 6
# 00:00:39,770 --> 00:00:41,860
# 0
# 매일 수천 명의 사람들이 일하러 가는
# 매
# 7
# 7
# 00:00:42,100 --> 00:00:44,870
# 0
# 블라드미르 리치 레닌 핵발전소
# 블
# 8
# 8
# 00:00:45,110 --> 00:00:48,340
# 0
# 오늘 저녁, 4호기의 176명 직원들이
# 오
# 9
# 9
# 00:00:48,580 --> 00:00:50,130
# 0
# 핵로의 자체 연료공급 시스템을
# 핵
# 10
# 1
# 00:00:50,380 --> 00:00:52,810
# 0
# 시험하고 있었다.
# 시
# 11
# 1
# 00:00:53,210 --> 00:00:55,440
# 0
# 에너지를 줄일 수 그 무엇...
# 에
# 12
# 1
# 00:00:56,380 --> 00:01:02,390
# 0
# 오전 1시 23분
# 오
# 안전장치를 해제하고 실험이 시작됐다.
# 안
# 14
# 1
# 00:01:06,660 --> 00:01:10,030
# 0
# ...

# %%
# line = 'been interesting.'

# print(re.search('[^<*>$]',line))
print(error_lst)
print(len(error_lst))
# Out:
# ['C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\apostle.2018.1080p.nf.web-dl.dd5.1.h264-cmrg.eng (1).srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\bag.of.bones.part.1.hdtv.xvid-fqm.srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\bag.of.bones.part.2.hdtv.xvid-fqm.srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\battle.2018.1080p.nf.web-dl.eng (1).srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\battle.2018.1080p.nf.web-dl.eng (2).srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\battle.2018.1080p.nf.web-dl.nor (1).srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\battle.2018.1080p.nf.web-dl.nor (2).srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\battle.2018.1080p.nf.web-dl.nor.srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\bird.box.2018.1080p.nf.web-dl.eng.sdh.srt', 'C:\\Users\\CHS\\Desktop\\wcoding\\data\\영화크롤링.vol2\\자막\\bleach.2018.1080p.nf.web-dl.ddp5.1.x26
# ...

# %%
# def isHangul(textss):
   
#     hangul = re.search('[ㄱ-ㅣ가-힣]+',textss)
#     print(hangul)

textss = '가난다s   ss'

# isHangul(textss)
print(textss.upper())
    
# print(re.search('[ㄱ-ㅣ가-힣]+',textss))
# Out:
# 가난다S   SS

# %%
# file_name = '[영어]밤을 즐겁게 (Pillow Talk , 1959) DVDRip.XviD.AC3 - SMF'
file_name = 'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\[eng]guzoo.srt'

print(re.search(r'(\[영어+\]|\[eng+\])',file_name.lower()))

print(file_name.lower().endswith('srt'))



if re.search(r'(\[영어+\]|\[eng+\])',file_name.lower()) is not None:
    print('^^')
# Out:
#   File "<ipython-input-184-30565d3a170d>", line 2
#     file_name = 'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\[eng]guzoo.srt'
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import os
import re
import glob












def srt_f(f_in,input_file_name,output_file_name):
    
    
    
    if input_file_name.endswith('.srt'):
        f_out = open(output_file_name, 'w',encoding='utf-8-sig')
    else :
        f_out = open(output_file_name, 'w')
        
        

    lines = filter(None, (line.strip() for line in f_in) )

    seq_num = 0 
    
    switch =True
        
    print('제목제목',output_file_name)
    for line in lines:   

        try:       
             
            if int(line) < 9999:    
                
                if seq_num == 0:
                    seq_num = int(line)
                    seq_num = seq_num +1
                    
#                 print("line:",int(line)," seq_num:", seq_num)

                if abs(int(line) - seq_num) == 1: 
                    
                    seq_num = seq_num +1
                    
                    if switch == True:    
                        switch = False
                        pass
                    
                    else:    
                        f_out.write("\n")


                            
                else :
                    
                    
                    if abs(int(line)-seq_num) < 3:
                        
                        seq_num = int(line) + 2
                        f_out.write("\n")
                    
                        
                        
                    else: # script로 간주
                        
                        line = line + ' '
#                         print("numeric:",line)
                        f_out.write(line)                            
                        
     
    
                

        except:
            
            start_word=('자막','제공','제작','SUB','{','#','++',
                '번역','\"넷플릭스','최종수정','HTTP','SRT','수입','배급',
                '영상정보','제목','\"NETFLIX','SMI','IRATEMOTOR','SUBTITLE','제목',' ','수정 불허')

            stime_pattern = re.compile('(\d{2}:\d{2}:\d{2},)')     
        
            
            word = ['♪','<>','--','-','</>','¿','¡','#','/','♬','.','”','“']
            
                
            if  line.upper().startswith(start_word):
                continue


            if stime_pattern.match(line) is not None:
                continue
             


            for i in re.findall(r"<(.+?)>", line):
                line = line.replace(i,'')


            for w in word:
                line = line.replace(w,'') 
            
            
            if len(line.strip()) == 0:
                continue
            
            
            line = line.rstrip() + ' '
            f_out.write(line)

            
    f_out.close()




def make_file(f_in,input_file_name,path):
    
    global clear_dir
    global error_lst
    
    
    
    new_path =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text'
#     new_path =r'C:\Users\CHS\Desktop\wcoding\data'
    
    
    
    start_num = input_file_name.rfind('\\')
    output_file_name = input_file_name[start_num:-4]
    output_file_name = new_path + output_file_name + '.txt'



    
    
    f_out = open(input_file_name, 'r',encoding='utf-8-sig')

      
    check_num = 0  
    
    for i in f_out: 

        if check_num == 1 :
            break
            
        check_string = i.strip()
        check_num = check_num +1
    

    
    if check_string.startswith('<SAMI>'):
        f_out.close()
        pass
        
    else: 
        f_out.close()
        srt_f(f_in,input_file_name,output_file_name)
                
          
    


                


    
    
def encoding_func(input_file_name, path):
    
    global clear_dir
    global error_lst
    
    
    
#     encoding_lit =['ascii',
#                      'big5',
#                      'big5hkscs',
#                      'cp037',
#                      'cp273',
#                      'cp424',
#                      'cp437',
#                      'cp500',
#                      'cp720',
#                      'cp737',
#                      'cp775',
#                      'cp850',
#                      'cp852',
#                      'cp855',
#                      'cp856',
#                      'cp857',
#                      'cp858',
#                      'cp860',
#                      'cp861',
#                      'cp862',
#                      'cp863',
#                      'cp864',
#                      'cp865',
#                      'cp866',
#                      'cp869',
#                      'cp874',
#                      'cp875',
#                      'cp932',
#                      'cp949',
#                      'cp950',
#                      'cp1006',
#                      'cp1026',
#                      'cp1125',
#                      'cp1140',
#                      'cp1250',
#                      'cp1251',
#                      'cp1252',
#                      'cp1253',
#                      'cp1254',
#                      'cp1255',
#                      'cp1256',
#                      'cp1257',
#                      'cp1258',
#                      'cp65001',
#                      'euc_jp',
#                      'euc_jis_2004',
#                      'euc_jisx0213',
#                      'euc_kr',
#                      'gb2312',
#                      'gbk',
#                      'gb18030',
#                      'hz',
#                      'iso2022_jp',
#                      'iso2022_jp_1',
#                      'iso2022_jp_2',
#                      'iso2022_jp_2004',
#                      'iso2022_jp_3',
#                      'iso2022_jp_ext',
#                      'iso2022_kr',
#                      'latin_1',
#                      'iso8859_2',
#                      'iso8859_3',
#                      'iso8859_4',
#                      'iso8859_5',
#                      'iso8859_6',
#                      'iso8859_7',
#                      'iso8859_8',
#                      'iso8859_9',
#                      'iso8859_10',
#                      'iso8859_11',
#                      'iso8859_13',
#                      'iso8859_14',
#                      'iso8859_15',
#                      'iso8859_16',
#                      'johab',
#                      'koi8_r',
#                      'koi8_t',
#                      'koi8_u',
#                      'kz1048',
#                      'mac_cyrillic',
#                      'mac_greek',
#                      'mac_iceland',
#                      'mac_latin2',
#                      'mac_roman',
#                      'mac_turkish',
#                      'ptcp154',
#                      'shift_jis',
#                      'shift_jis_2004',
#                      'shift_jisx0213',
#                      'utf_32',
#                      'utf_32_be',
#                      'utf_32_le',
#                      'utf_16',
#                      'utf_16_be',
#                      'utf_16_le',
#                      'utf_7',
#                      'utf_8',
#                      'utf_8_sig']

    
    
    
    
#     try:
        
        
#         with open(input_file_name) as f_in:
#             make_file(f_in,input_file_name,path)
            
            
            
#     except:
        
      
#         for i in encoding_lit:
#             print(i)
#             try:
#                 with open(input_file_name) as f_in:
#                     make_file(f_in,input_file_name,path,encoding=i)
#                     break
                    
#             except:
#                 continue
    
    
      
        
#     f_in.close()





    
    try:
        with open(input_file_name) as f_in:
            make_file(f_in,input_file_name,path)
            print('$')
            
    except:
        
        try:
            with open(input_file_name,encoding='utf-8-sig') as f_in:
                make_file(f_in,input_file_name,path)
                print('$$')
        except:                     

            try:
#                 with open(input_file_name,encoding='latin1-sig') as f_in:
#                     make_file(f_in,input_file_name,path)
#                     print('#################')
                with open(input_file_name,encoding='cp866') as f_in:
                    make_file(f_in,input_file_name,path)
                    print('#################')
                
            except:
                print('\n[error]',input_file_name,'\n')
                
                error_lst.append(input_file_name)


            
    f_in.close()
    


def main():
    
    global error_lst
    global clear_dir
    
    
    
    p =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2'### 경로 설정해줄 것.
    new_path =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text'
    
    for(path, dir, files) in os.walk(p):
#         subtitle_list = glob.glob(path+'\\*.smi')
#         subtitle_list.extend(glob.glob(path+'\\*.srt'))
    
        subtitle_list = glob.glob(path+'\\*.srt')
    
    
    lang_word =('eng.srt','esp.srt','en.srt','english.srt','eng.srt')
    

    for file_name in subtitle_list:
                      
        if file_name.lower().endswith(lang_word):

            continue      
       
        if re.search(r'(영어.+|eng)',file_name.lower()) is not None:
            
            continue         
            
#         if re.search(r'(\[영어.+\]|\[eng.+\])',file_name.lower()) is not None:
#              print('@@')
#             continue

        error_t=encoding_func(file_name,p)
            
        

        
#     testt =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\a.prayer.before.dawn.2017.1080p.amzn.web-dl.ddp5.1.h.264-ntg.eng.srt' 
#     testt =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\[Shiniori-Raws]+009+Re+Cyborg+The+Movie+BD+1280x720+x264+AAC.srt'
#     error_t = encoding_func( testt , p )  
#     testt=r'‪C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\Miss+Representation.srt'
#     testt=r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\Mati+Suri+(2009).srt'
#     error_t = encoding_func( testt , p )
    
    
    
error_lst=[]
clear_dir=[]

if __name__ == '__main__':
    main()
# Out:
# 0 : file: C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text\aguirre.the.wrath.of.god.1972.txt
# first: 1
#
# second: 0
# third: 1
# forth: 1
# first: 00:00:00,406 --> 00:00:05,195
#
# second: 1
# ## 1
# $$$
# $
# 0 : file: C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text\anihls-ygotmpol2d.720p.bluray (1).txt
# 0 : file: C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text\anihls-ygotmpol2d.720p.bluray (1).txt
#
# [error] C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\anihls-ygotmpol2d.720p.bluray (1).srt
#
# 0 : file: C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text\anihls-ygotmpol2d.720p.bluray.txt
# 0 : file: C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text\anihls-ygotmpol2d.720p.bluray.txt
#
# [error] C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\anihls-ygotmpol2d.720p.bluray.srt
#
# 0 : file: C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text\bag.of.bones.part.1.hdtv.xvid-fqm.txt
# first: 2
#
# second: 0
# third: 2
# forth: 1
# first: 00:00:17,755 --> 00:00:20,555
#
# ...

# %%
test = '1\n가나다'
# print(test)

file = r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2\자막\[Discovery2006_0503]+The+Battle+Of+Chernobyl.srt'

f_out = open(file, 'r',encoding='utf-8-sig')

a = 0

for i in f_out:
   
    if a == 1:
        print("###")
        f_out.close()
        break
    num = i.strip()
    a = a+1

if int(num) == 1:
    print('correct')
# Out:
# ###
# correct

# %%
import pandas as pd

for



txt =r'C:\Users\CHS\Desktop\wcoding\data\영화크롤링.vol2_text\[2001] 해리 포터와 마법사의 돌 Harry Potter and the Philosophers Stone.txt'


f = open(txt, 'r',encoding='utf-8-sig')
data = f.read()

subtitle = txt[txt.rfind('\\')+1:-4]
print(title)

    
df = {'subtitle':[subtitle],'txt':[data]}
matrix = pd.DataFrame(df,columns=['subtitle','txt'])
print(matrix.info())






    f_out = open(file, 'r',encoding='utf-8-sig')

      
    check_num = 0   
    for i in f_out:  
        if check_num == 1 :
#             f_out.close()
            break
        check_string = i.strip()
        check_num = check_num +1
      
    
    print(check_string)
    
    if check_string.startswith('<SAMI>'):
        pass
        
    else: 
        srt_f(f_in,input_file_name,output_file_name)
                
          
    

    f_out.close()
# Out:
#   File "<ipython-input-272-a2ca13b2dcb8>", line 3
#     for
#        ^
# SyntaxError: invalid syntax

# %%
p = r'C:\Users\CHS\Desktop\test'   ### 경로 설정해줄 것.

txt_lst=[]
subtitle_lst=[]

for(path, dir, files) in os.walk(p):
    txt_lst = glob.glob(path+'\\*.txt')
    print(txt_lst)
    
for txt in txt_lst:
#     print(txt)
    try:
        f = open(txt, 'r',encoding='utf-8')
        data = f.read()
#         print(data)
    except:
        f = open(txt, 'r', encoding='latin1')
        data = f.read()
#         print(data)
        
    subtitle_lst.append(data)
    f.close()

# print(subtitle_lst)
    
word=['.','','”','“','수정 불허  자유 배포','!']

for i in range(len(txt_lst)):
    txt_lst[i]= txt_lst[i][txt_lst[i].rfind('\\')+1:-4]

for j in range(len(subtitle_lst)):
    
    subtitle_lst[j]=re.sub('<\font>',' ',subtitle_lst[j])
    subtitle_lst[j]=re.sub('  ',' ',subtitle_lst[j])
    subtitle_lst[j]=re.sub('sub2smi by|자막 제작|年$','',subtitle_lst[j])
    
print(txt_lst[0])
print(len(subtitle_lst))
# Out:
# ['C:\\Users\\CHS\\Desktop\\test\\love.simon.2018.1080p.bluray.kor.txt', 'C:\\Users\\CHS\\Desktop\\test\\Memoirs.of.a.Geisha.2005.1080p.BluRay.AVC.LPCM.5.1-FGT.txt', 'C:\\Users\\CHS\\Desktop\\test\\Memories.Of.Murder.2003.1080p.BluRay.x264.AC3-oOo.txt', 'C:\\Users\\CHS\\Desktop\\test\\the.winter.war.1989.1080p.bluray.x264-usury.kor.txt', 'C:\\Users\\CHS\\Desktop\\test\\World.War.Z.2013.1080p.BluRay.x264.YIFY.txt', 'C:\\Users\\CHS\\Desktop\\test\\X-Men.Days.of.Future.Past.2014.THE.ROGUE.CUT.1080p.BluRay.H264.AAC-RARBG.txt', 'C:\\Users\\CHS\\Desktop\\test\\zodiac.2007.1080p.bluray.kor_원본.txt', 'C:\\Users\\CHS\\Desktop\\test\\그리고 신은 여자를 창조했다 (And God Created Woman , 1956) Bluray.720p.x264 - EbP [PublicHD].txt', 'C:\\Users\\CHS\\Desktop\\test\\라이프 Life, 2017.1080p.Blu-ray.AVC.DTS-HD.MA.7.1-sgNb@CHDBits.kor.txt', 'C:\\Users\\CHS\\Desktop\\test\\잭 더 자이언트 킬러 (Jack The Giant Killer , 2013) BluRay.1080p.x264 - SPARKS [PublicHD].txt']
# love.simon.2018.1080p.bluray.kor
# 10

# %%
import pandas as pd

a =[1531,4611,10323,38263,33795,24643,19411,36479,8346,37981]
    
data = {'title':txt_lst,'subtitle':subtitle_lst,'movie_id':a}
df = pd.DataFrame(data,columns=['title','subtitle','movie_id'])


df.to_csv(r"C:\Users\CHS\Desktop\test_table\movie_sample.csv",header=True, index= False ,encoding='utf-8-sig')

# %%
data_f = pd.read_csv(r"C:\Users\CHS\Desktop\test_table\movie_sample.csv")


print(data_f)
# Out:
#                                                title  \
# 0                   love.simon.2018.1080p.bluray.kor
# 1  Memoirs.of.a.Geisha.2005.1080p.BluRay.AVC.LPCM...
# 2  Memories.Of.Murder.2003.1080p.BluRay.x264.AC3-oOo
# 3    the.winter.war.1989.1080p.bluray.x264-usury.kor
# 4            World.War.Z.2013.1080p.BluRay.x264.YIFY
# 5  X-Men.Days.of.Future.Past.2014.THE.ROGUE.CUT.1...
# 6                    zodiac.2007.1080p.bluray.kor_원본
# 7  그리고 신은 여자를 창조했다 (And God Created Woman , 1956)...
# 8  라이프 Life, 2017.1080p.Blu-ray.AVC.DTS-HD.MA.7.1...
# 9  잭 더 자이언트 킬러 (Jack The Giant Killer , 2013) Blu...
#
#                                             subtitle  movie_id
# 0  ﻿나도 너와 똑같아 \n여러모로 평범하지 \n생일 축하해 \n와! \n꽃미남 쿼터백...      1531
# 1  ﻿게이샤의 추억 \n아빠도 올 거죠? \n괜찮아 \n아빠가 걱정돼요 \n우리 어디 ...      4611
# 2  ﻿똥차! 똥차! \n야! 너 여기 있지 말구 저쪽으로 가 \n야! 너 저쪽으로 가라...     10323
# 3  ﻿이영화를 소련과 겨울전쟁에 헌신한 핀란드 국민들에게 바칩니다 \n1939년12월2...     38263
# 4  ﻿한글 번역 by Subo \n안녕하십니까, JVL 아침 뉴스입니다 \n 시청해 주...     33795
# ...

# %%
from peewee import *
from playhouse.db_url import connect


movie_db = connect('mysql://movie:qwer1212@localhost:127.0.0.1/movie_search')


def db_connect():

    movie_db.connect()

    
    
def insert_interest():

    with open(r"C:\Users\CHS\Desktop\test_table\movie_sample.csv" , encoding = 'utf-8-sig') as data_file:
        reader = list(csv.reader(data_file, delimiter=',', quotechar='"'))
        reader.remove(reader[0])
        for row in reader:
            subtitle_all.insert( subtitle = row[1], movie_id = row[2]).execute()
            
            
            


if __name__ == '__main__':
   
    db_connect()
#     insert_interest()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-67321c209740> in <module>
#       3
#       4
# ----> 5 movie_db = connect('mysql://movie:qwer1212@localhost:127.0.0.1/movie_search')
#       6
#       7
#
# ~\Anaconda3\lib\site-packages\playhouse\db_url.py in connect(url, unquote_password, **connect_params)
#      85 def connect(url, unquote_password=False, **connect_params):
#      86     parsed = urlparse(url)
# ---> 87     connect_kwargs = parseresult_to_dict(parsed, unquote_password)
#      88     connect_kwargs.update(connect_params)
#      89     database_class = schemes.get(parsed.scheme)
#
# ~\Anaconda3\lib\site-packages\playhouse\db_url.py in parseresult_to_dict(parsed, unquote_password)
#      49     if parsed.hostname:
#      50         connect_kwargs['host'] = parsed.hostname
# ---> 51     if parsed.port:
# ...

# %%
import peewee
from peewee import *


movie_db = MySQLDatabase('movie_search', user='movie', password='qwer1212',
                         host='127.0.0.1', port=5000)


def db_connect():

    movie_db.connect()

    
    
def insert_interest():

    with open(r"C:\Users\CHS\Desktop\test_table\movie_sample.csv" , encoding = 'utf-8-sig') as data_file:
        reader = list(csv.reader(data_file, delimiter=',', quotechar='"'))
        reader.remove(reader[0])
        for row in reader:
            subtitle_all.insert( subtitle = row[1], movie_id = row[2]).execute()
            
            
            


if __name__ == '__main__':
   
    db_connect()
    insert_interest()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
with open(r"C:\Users\CHS\Desktop\test_table\movie_sample.csv" , encoding = 'utf-8-sig') as data_file:
    reader = list(csv.reader(data_file, delimiter=',', quotechar='"'))

for i in reader:
    print(i[0])
# Out:
# title
# love.simon.2018.1080p.bluray.kor
# Memoirs.of.a.Geisha.2005.1080p.BluRay.AVC.LPCM.5.1-FGT
# Memories.Of.Murder.2003.1080p.BluRay.x264.AC3-oOo
# the.winter.war.1989.1080p.bluray.x264-usury.kor
# World.War.Z.2013.1080p.BluRay.x264.YIFY
# X-Men.Days.of.Future.Past.2014.THE.ROGUE.CUT.1080p.BluRay.H264.AAC-RARBG
# zodiac.2007.1080p.bluray.kor_원본
# 그리고 신은 여자를 창조했다 (And God Created Woman , 1956) Bluray.720p.x264 - EbP [PublicHD]
# 라이프 Life, 2017.1080p.Blu-ray.AVC.DTS-HD.MA.7.1-sgNb@CHDBits.kor
# 잭 더 자이언트 킬러 (Jack The Giant Killer , 2013) BluRay.1080p.x264 - SPARKS [PublicHD]
