# %%
import requests
from bs4 import BeautifulSoup
import os
import time
import telegram
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize
import re

# Input: rcp_no

def get_report_attach_urls(rcp_no):
    
    excel_link_tmpl = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no={rcp_no}&dcm_no={dcm_no}&lang=ko"
    
    attach_urls = []

    url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=%s" % (rcp_no)
    r = requests.get(url)

    start_str = "javascript: viewDoc\('" + rcp_no + "', '"
    end_str = "', null, null, null,"
    reg = re.compile(start_str + '(.*)' + end_str)
    m = reg.findall(r.text)
    dcm_no = m[0]


    attach_urls = excel_link_tmpl.format(rcp_no=rcp_no, dcm_no= dcm_no)
    print(attach_urls)
    return attach_urls


import pandas as pd

url = get_report_attach_urls('20190401004781')

df = pd.read_excel(url, sheet_name='재무상태표', index_col=0, skiprows=6)
# Out:
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20190401004781&dcm_no=6616741&lang=ko

# %%
df.head(30)
# Out:
#                                  제 50 기     제 49 기     제 48 기
#
# 자산
#     유동자산                       80039455   70155189   69981128
#         현금및현금성자산                2607957    2763768    3778371
#         단기금융상품                 34113871   25510064   30170656
#         매출채권                   24933267   27881777   23514012
#         미수금                     1515079    2201402    2319782
#         선급금                      807262    1097598     814300
#         선급비용                    2230628    2281179    2375520
#         재고자산                   12440951    7837144    5981634
#         기타유동자산                  1390440     582257     743163
#         매각예정분류자산                                       283690
#     비유동자산                     138981902  128086171  104821831
#         장기매도가능금융자산                          973353     913989
#         기타포괄손익-공정가치금융자산         1098565
#         당기손익-공정가치금융자산              7413
#         종속기업, 관계기업 및 공동기업 투자   55959745   55671759   48743079
#         유형자산                   70602493   62816961   47228830
#         무형자산                    2901476    2827035    2891844
#         장기선급비용                  4108410    3031327    3507399
#         순확정급여자산                  562356     811210     557091
#         이연법인세자산                  654456     586161     110239
#         기타비유동자산                 3086988    1368365     869360
#     자산총계                      219021357  198241360  174802959
# 부채
#     유동부채                       43145053   44495084   34076122
#         매입채무                    7315631    6398629    6162650
#         단기차입금                  10353873   12229701    9061167
#         미지급금                    8385752    9598654    7635740
#         선수금                      214615     214007     200445
#         예수금                      572702     500740     389528

# %% [markdown]
# ### 항목 분류컬럼생성

# %%
# 공백개수로 분류하여 리스트화 : hier_num

##가정1. 재무상태표 항목입력 시 계층 상하관계에따라 공백을 달리 표시했다.

hier_num = sorted(set([ len(i) - len(i.lstrip()) for i in df2.index]))




# 컬럼 추가( hier_num 리스트 분류 만큼 )
a_col=[]
for i in range(len(hier_num)):

    name = '분류{}'.format(i)
    a_col.append(name)
    df2[name]= ''

# %% [markdown]
# ### 항목 분류컬럼 값 채우기

# %%
# 계층구조에 맞게 컬럼값 채우기

##가정1. 첫 행렬값이 가장 최상위 계층이다.
##가정2. 계정항목들은 상하관계에 따라 순차적으로 정렬되어있다.
##가정3: 하위계층을 가지는 항목을 가지는 데이터는 사용할 필요가 없다.

rm_idx_list = []


before = 0



for ix,i in enumerate(df2.index):
    
    
    
    a = len(i)-len(i.lstrip())
    
    #하위계층인지 체크
    if  a > before:
               
        rm_idx_list.append(ix-1)  # 해당 항목이 앞선항목의 하위항목에 해당된다면, 이전 항목의 row index를 저장하라
 

        #계층컬럼값 채우기
        for j in hier_num: 

            if j == a:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = i.strip()
                
                break


            else:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = df2.iloc[ix-1,b].strip()
        
        
        
        
        before = a



    else:   
        
        
        #계층컬럼값 채우기
        for j in hier_num: 

            if j == a:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = i.strip()
                
                break


            else:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = df2.iloc[ix-1,b].strip()
                
                
        
        before = a

# %% [markdown]
# ### 하위계층을 더이상 갖지 않는 항목의 레코드만 추출 & 총계를 표시하는 레코드 제외

# %%
set1 = set(range(len(df2))) 

set2 = set(rm_idx_list)

rows_to_use = list(set1.difference(set2))


df3 = df2.iloc[rows_to_use]
df3 = df3[df3.index.str.contains('총계') == False ]

# %%
df3

# %% [markdown]
# ### '분기' 컬럼을 로우로 변환

# %%
df3.index.name = '항목명'

df4 = df3.reset_index()

df5 = pd.melt(df4, id_vars=['항목명','분류0','분류1','분류2'],var_name=['분기'])

df5 = df5.rename(columns={'value':'금액'})

# %% [markdown]
# <br><br><br><br>
#
#
# # 통합 code

# %%
import requests
from bs4 import BeautifulSoup
import os
import time
import telegram
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize
import re

#################################################################
def get_report_attach_urls(rcp_no):
    
    excel_link_tmpl = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no={rcp_no}&dcm_no={dcm_no}&lang=ko"
    
    attach_urls = []

    url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=%s" % (rcp_no)
    r = requests.get(url)

    start_str = "javascript: viewDoc\('" + rcp_no + "', '"
    end_str = "', null, null, null,"
    reg = re.compile(start_str + '(.*)' + end_str)
    m = reg.findall(r.text)
    dcm_no = m[0]


    attach_urls = excel_link_tmpl.format(rcp_no=rcp_no, dcm_no= dcm_no)

    return attach_urls




def preprocessing(data,rm_idx_list,elem_list):
    
    global bs_table
    
    #최하위계층 항목만 추출
    set1 = set(range(len(data))) 

    set2 = set(rm_idx_list)

    rows_to_use = list(set1.difference(set2))
    
    df3 = data.iloc[rows_to_use]
    
    
    #'총계' 레코드 제외
    df3 = df3[df3.index.str.contains('총계') == False ]


    
    # 컬럼명을 컬럼값으로 내리기
    
    df3.index.name = '항목명'
    df4 = df3.reset_index()    
    
    id_vars = ['항목명']
    id_vars.extend(elem_list)   
    df5 = pd.melt(df4, id_vars= id_vars,var_name=['분기'])


    bs_table = df5.rename(columns={'value':'금액'})
    
    
    
#     #부모계층컬럼생성
#     bs_table['parent'] =''


#     for ix,row in bs_table[a_col].iterrows():

#         rows= [x for x in row if x]
#         bs_table['parent'][ix] = rows[-1]

        
        
##############################################################




url = get_report_attach_urls('20190401004781')  # 20190401004781 는 rcp_no , 문서접수번호(고유번호)

df = pd.read_excel(url, sheet_name='재무상태표', index_col=0, skiprows=6)

df2 =df




# 공백개수로 분류하여 리스트화 : hier_num

##가정1. 재무상태표 항목입력 시 계층 상하관계에따라 공백을 달리 표시했다.

hier_num = sorted(set([ len(i) - len(i.lstrip()) for i in df2.index]))



# 컬럼 추가( hier_num 리스트 분류 만큼 )
a_col=[]
for i in range(len(hier_num)):

    name = '분류{}'.format(i+1)
    a_col.append(name)
    df2[name]= ''

    
    
    
# 계층구조에 맞게 컬럼값 채우기

##가정1. 첫 행렬값이 가장 최상위 계층이다.
##가정2. 계정항목들은 상하관계에 따라 순차적으로 정렬되어있다.
##가정3: 하위계층을 가지는 항목을 가지는 데이터는 사용할 필요가 없다.

rm_idx_list = []


before = 0



for ix,i in enumerate(df2.index):
    
    
    
    a = len(i)-len(i.lstrip())
    
    #하위계층인지 체크
    if  a > before:
               
        rm_idx_list.append(ix-1)  # 해당 항목이 앞선항목의 하위항목에 해당된다면, 이전 항목의 row index를 저장하라
 

        #계층컬럼값 채우기
        for j in hier_num: 

            if j == a:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = i.strip()
                
                break


            else:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = df2.iloc[ix-1,b].strip()
        
        
        
        
        before = a



    else:   
        
        
        #계층컬럼값 채우기
        for j in hier_num: 

            if j == a:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = i.strip()
                
                break


            else:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = df2.iloc[ix-1,b].strip()
                
                
        
        before = a
        
        
        

        

# 실행 : output -> DB에 저장될  " bs_table ""  생성


preprocessing(df2,rm_idx_list,a_col)

# %%
bs_table.to_csv('C:/DATA/BS_TABLE1.csv',index=True , header =True,encoding='ms949')

# %% [markdown]
# # hierarchical data.

# %%
import requests
from bs4 import BeautifulSoup
import os
import time
import telegram
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize
import re

#################################################################
def get_report_attach_urls(rcp_no):
    
    excel_link_tmpl = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no={rcp_no}&dcm_no={dcm_no}&lang=ko"
    
    attach_urls = []

    url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=%s" % (rcp_no)
    r = requests.get(url)

    start_str = "javascript: viewDoc\('" + rcp_no + "', '"
    end_str = "', null, null, null,"
    reg = re.compile(start_str + '(.*)' + end_str)
    m = reg.findall(r.text)
    dcm_no = m[0]


    attach_urls = excel_link_tmpl.format(rcp_no=rcp_no, dcm_no= dcm_no)

    return attach_urls



url = get_report_attach_urls('20190401004781')  # 20190401004781 는 rcp_no , 문서접수번호(고유번호)

df = pd.read_excel(url, sheet_name='재무상태표', index_col=0, skiprows=6)



df.index.name = '항목명'
df2 = df.reset_index()    


df3 = pd.melt(df2,id_vars=['항목명'], var_name=['분기'])


df3.to_csv('C:/DATA/df3.csv',index=True , header =True,encoding='ms949')

# df2

# %%
bs_table
# Out:
#                          항목명 분류1         분류2              분류3     분류4      분기  \
# 0                   현금및현금성자산  자산        유동자산         현금및현금성자산          제 50 기
# 1                     단기금융상품  자산        유동자산           단기금융상품          제 50 기
# 2                 단기매도가능금융자산  자산        유동자산       단기매도가능금융자산          제 50 기
# 3                단기상각후원가금융자산  자산        유동자산      단기상각후원가금융자산          제 50 기
# 4            단기당기손익-공정가치금융자산  자산        유동자산  단기당기손익-공정가치금융자산          제 50 기
# 5                       매출채권  자산        유동자산             매출채권          제 50 기
# 6                        미수금  자산        유동자산              미수금          제 50 기
# 7                        선급금  자산        유동자산              선급금          제 50 기
# 8                       선급비용  자산        유동자산             선급비용          제 50 기
# 9                       재고자산  자산        유동자산             재고자산          제 50 기
# 10                    기타유동자산  자산        유동자산           기타유동자산          제 50 기
# 11                  매각예정분류자산  자산        유동자산         매각예정분류자산          제 50 기
# 12                장기매도가능금융자산  자산       비유동자산       장기매도가능금융자산          제 50 기
# 13                  만기보유금융자산  자산       비유동자산         만기보유금융자산          제 50 기
# 14                 상각후원가금융자산  자산       비유동자산        상각후원가금융자산          제 50 기
# 15           기타포괄손익-공정가치금융자산  자산       비유동자산  기타포괄손익-공정가치금융자산          제 50 기
# 16             당기손익-공정가치금융자산  자산       비유동자산    당기손익-공정가치금융자산          제 50 기
# 17            관계기업 및 공동기업 투자  자산       비유동자산   관계기업 및 공동기업 투자          제 50 기
# 18                      유형자산  자산       비유동자산             유형자산          제 50 기
# 19                      무형자산  자산       비유동자산             무형자산          제 50 기
# 20                    장기선급비용  자산       비유동자산           장기선급비용          제 50 기
# 21                   순확정급여자산  자산       비유동자산          순확정급여자산          제 50 기
# 22                   이연법인세자산  자산       비유동자산          이연법인세자산          제 50 기
# 23                   기타비유동자산  자산       비유동자산          기타비유동자산          제 50 기
# 24                      매입채무  부채        유동부채             매입채무          제 50 기
# 25                     단기차입금  부채        유동부채            단기차입금          제 50 기
# 26                      미지급금  부채        유동부채             미지급금          제 50 기
# 27                       선수금  부채        유동부채              선수금          제 50 기
# 28                       예수금  부채        유동부채              예수금          제 50 기
# 29                     미지급비용  부채        유동부채            미지급비용          제 50 기
# ..                       ...  ..         ...              ...     ...     ...
# 117                     무형자산  자산       비유동자산             무형자산          제 48 기
# 118                   장기선급비용  자산       비유동자산           장기선급비용          제 48 기
# 119                  순확정급여자산  자산       비유동자산          순확정급여자산          제 48 기
# 120                  이연법인세자산  자산       비유동자산          이연법인세자산          제 48 기
# 121                  기타비유동자산  자산       비유동자산          기타비유동자산          제 48 기
# 122                     매입채무  부채        유동부채             매입채무          제 48 기
# 123                    단기차입금  부채        유동부채            단기차입금          제 48 기
# 124                     미지급금  부채        유동부채             미지급금          제 48 기
# 125                      선수금  부채        유동부채              선수금          제 48 기
# 126                      예수금  부채        유동부채              예수금          제 48 기
# 127                    미지급비용  부채        유동부채            미지급비용          제 48 기
# 128                   미지급법인세  부채        유동부채           미지급법인세          제 48 기
# 129                  유동성장기부채  부채        유동부채          유동성장기부채          제 48 기
# 130                     충당부채  부채        유동부채             충당부채          제 48 기
# 131                   기타유동부채  부채        유동부채           기타유동부채          제 48 기
# 132                 매각예정분류부채  부채        유동부채         매각예정분류부채          제 48 기
# 133                       사채  부채       비유동부채               사채          제 48 기
# 134                    장기차입금  부채       비유동부채            장기차입금          제 48 기
# 135                   장기미지급금  부채       비유동부채           장기미지급금          제 48 기
# 136                  순확정급여부채  부채       비유동부채          순확정급여부채          제 48 기
# 137                  이연법인세부채  부채       비유동부채          이연법인세부채          제 48 기
# 138                   장기충당부채  부채       비유동부채           장기충당부채          제 48 기
# 139                  기타비유동부채  부채       비유동부채          기타비유동부채          제 48 기
# 140                   우선주자본금  자본  지배기업 소유주지분              자본금  우선주자본금  제 48 기
# 141                   보통주자본금  자본  지배기업 소유주지분              자본금  보통주자본금  제 48 기
# 142                  주식발행초과금  자본  지배기업 소유주지분          주식발행초과금          제 48 기
# 143                    이익잉여금  자본  지배기업 소유주지분            이익잉여금          제 48 기
# 144                   기타자본항목  자본  지배기업 소유주지분           기타자본항목          제 48 기
# 145             매각예정분류기타자본항목  자본  지배기업 소유주지분     매각예정분류기타자본항목          제 48 기
# 146                    비지배지분  자본       비지배지분                           제 48 기
#
#             금액
# 0     30340505
# 1     65893797
# 2
# 3      2703693
# 4      2001948
# 5     33867733
# 6      3080733
# 7      1361807
# 8      4136167
# 9     28984704
# 10     2326337
# 11
# 12
# 13
# 14      238309
# 15     7301351
# 16      775427
# 17     7313206
# 18   115416724
# 19    14891598
# 20     5009679
# 21      562356
# 22     5468002
# 23     7683168
# 24     8479916
# 25    13586660
# 26    10711536
# 27      820265
# 28      951254
# 29    20339687
# ..         ...
# 117    5344020
# 118    3834831
# 119     557091
# 120    5321450
# 121    1572027
# 122    6485039
# 123   12746789
# 124   11525910
# 125    1358878
# 126     685028
# 127   12527300
# 128    2837353
# 129    1232817
# 130    4597417
# 131     351176
# 132     356388
# 133      58542
# 134    1244238
# 135    3317054
# 136     173656
# 137    7293514
# 138     358126
# 139    2062066
# 140     119467
# 141     778047
# 142    4403893
# 143  193086317
# 144  -11934586
# 145     -28810
# 146    6538705
#
# [147 rows x 7 columns]
