# %%
import requests
from bs4 import BeautifulSoup
import os
import time
import telegram
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize
import re

# Input: rcp_no

def get_report_attach_urls(rcp_no):
    
    excel_link_tmpl = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no={rcp_no}&dcm_no={dcm_no}&lang=ko"
    
    attach_urls = []

    url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=%s" % (rcp_no)
    r = requests.get(url)

    start_str = "javascript: viewDoc\('" + rcp_no + "', '"
    end_str = "', null, null, null,"
    reg = re.compile(start_str + '(.*)' + end_str)
    m = reg.findall(r.text)
    dcm_no = m[0]


    attach_urls = excel_link_tmpl.format(rcp_no=rcp_no, dcm_no= dcm_no)
    print(attach_urls)
    return attach_urls


import pandas as pd

url = get_report_attach_urls('20190401004781')

df = pd.read_excel(url, sheet_name='재무상태표', index_col=0, skiprows=6)
# Out:
# http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20190401004781&dcm_no=6616741&lang=ko

# %%
df.head(30)
# Out:
#                                  제 50 기     제 49 기     제 48 기
#
# 자산
#     유동자산                       80039455   70155189   69981128
#         현금및현금성자산                2607957    2763768    3778371
#         단기금융상품                 34113871   25510064   30170656
#         매출채권                   24933267   27881777   23514012
#         미수금                     1515079    2201402    2319782
#         선급금                      807262    1097598     814300
#         선급비용                    2230628    2281179    2375520
#         재고자산                   12440951    7837144    5981634
#         기타유동자산                  1390440     582257     743163
#         매각예정분류자산                                       283690
#     비유동자산                     138981902  128086171  104821831
#         장기매도가능금융자산                          973353     913989
#         기타포괄손익-공정가치금융자산         1098565
#         당기손익-공정가치금융자산              7413
#         종속기업, 관계기업 및 공동기업 투자   55959745   55671759   48743079
#         유형자산                   70602493   62816961   47228830
#         무형자산                    2901476    2827035    2891844
#         장기선급비용                  4108410    3031327    3507399
#         순확정급여자산                  562356     811210     557091
#         이연법인세자산                  654456     586161     110239
#         기타비유동자산                 3086988    1368365     869360
#     자산총계                      219021357  198241360  174802959
# 부채
#     유동부채                       43145053   44495084   34076122
#         매입채무                    7315631    6398629    6162650
#         단기차입금                  10353873   12229701    9061167
#         미지급금                    8385752    9598654    7635740
#         선수금                      214615     214007     200445
#         예수금                      572702     500740     389528

# %% [markdown]
# ### 항목 분류컬럼생성

# %%
# 공백개수로 분류하여 리스트화 : hier_num

##가정1. 재무상태표 항목입력 시 계층 상하관계에따라 공백을 달리 표시했다.

hier_num = sorted(set([ len(i) - len(i.lstrip()) for i in df2.index]))




# 컬럼 추가( hier_num 리스트 분류 만큼 )
a_col=[]
for i in range(len(hier_num)):

    name = '분류{}'.format(i)
    a_col.append(name)
    df2[name]= ''

# %% [markdown]
# ### 항목 분류컬럼 값 채우기

# %%
# 계층구조에 맞게 컬럼값 채우기

##가정1. 첫 행렬값이 가장 최상위 계층이다.
##가정2. 계정항목들은 상하관계에 따라 순차적으로 정렬되어있다.
##가정3: 하위계층을 가지는 항목을 가지는 데이터는 사용할 필요가 없다.

rm_idx_list = []


before = 0



for ix,i in enumerate(df2.index):
    
    
    
    a = len(i)-len(i.lstrip())
    
    #하위계층인지 체크
    if  a > before:
               
        rm_idx_list.append(ix-1)  # 해당 항목이 앞선항목의 하위항목에 해당된다면, 이전 항목의 row index를 저장하라
 

        #계층컬럼값 채우기
        for j in hier_num: 

            if j == a:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = i.strip()
                
                break


            else:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = df2.iloc[ix-1,b].strip()
        
        
        
        
        before = a



    else:   
        
        
        #계층컬럼값 채우기
        for j in hier_num: 

            if j == a:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = i.strip()
                
                break


            else:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = df2.iloc[ix-1,b].strip()
                
                
        
        before = a

# %% [markdown]
# ### 하위계층을 더이상 갖지 않는 항목의 레코드만 추출 & 총계를 표시하는 레코드 제외

# %%
set1 = set(range(len(df2))) 

set2 = set(rm_idx_list)

rows_to_use = list(set1.difference(set2))


df3 = df2.iloc[rows_to_use]
df3 = df3[df3.index.str.contains('총계') == False ]

# %%
df3

# %% [markdown]
# ### '분기' 컬럼을 로우로 변환

# %%
df3.index.name = '항목명'

df4 = df3.reset_index()

df5 = pd.melt(df4, id_vars=['항목명','분류0','분류1','분류2'],var_name=['분기'])

df5 = df5.rename(columns={'value':'금액'})

# %% [markdown]
# <br><br><br><br>
#
#
# # 통합 code

# %%
import requests
from bs4 import BeautifulSoup
import os
import time
import telegram
import numpy as np
import pandas as pd
import json
from pandas.io.json import json_normalize
import re

#################################################################
def get_report_attach_urls(rcp_no):
    
    excel_link_tmpl = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no={rcp_no}&dcm_no={dcm_no}&lang=ko"
    
    attach_urls = []

    url = "http://dart.fss.or.kr/dsaf001/main.do?rcpNo=%s" % (rcp_no)
    r = requests.get(url)

    start_str = "javascript: viewDoc\('" + rcp_no + "', '"
    end_str = "', null, null, null,"
    reg = re.compile(start_str + '(.*)' + end_str)
    m = reg.findall(r.text)
    dcm_no = m[0]


    attach_urls = excel_link_tmpl.format(rcp_no=rcp_no, dcm_no= dcm_no)

    return attach_urls




def preprocessing(data,rm_idx_list,elem_list):
    
    global bs_table
    
    set1 = set(range(len(data))) 

    set2 = set(rm_idx_list)

    rows_to_use = list(set1.difference(set2))


    df3 = data.iloc[rows_to_use]
    df3 = df3[df3.index.str.contains('총계') == False ]


    df3.index.name = '항목명'


    df4 = df3.reset_index()
    
    
    id_vars = ['항목명']

    id_vars.extend(elem_list)
    

    df5 = pd.melt(df4, id_vars= id_vars,var_name=['분기'])


    bs_table = df5.rename(columns={'value':'금액'})

##############################################################




url = get_report_attach_urls('20190401004781')  # 20190401004781 는 rcp_no , 문서접수번호(고유번호)

df = pd.read_excel(url, sheet_name='재무상태표', index_col=0, skiprows=6)

df2 =df




# 공백개수로 분류하여 리스트화 : hier_num

##가정1. 재무상태표 항목입력 시 계층 상하관계에따라 공백을 달리 표시했다.

hier_num = sorted(set([ len(i) - len(i.lstrip()) for i in df2.index]))



# 컬럼 추가( hier_num 리스트 분류 만큼 )
a_col=[]
for i in range(len(hier_num)):

    name = '분류{}'.format(i+1)
    a_col.append(name)
    df2[name]= ''

    
    
    
# 계층구조에 맞게 컬럼값 채우기

##가정1. 첫 행렬값이 가장 최상위 계층이다.
##가정2. 계정항목들은 상하관계에 따라 순차적으로 정렬되어있다.
##가정3: 하위계층을 가지는 항목을 가지는 데이터는 사용할 필요가 없다.

rm_idx_list = []


before = 0



for ix,i in enumerate(df2.index):
    
    
    
    a = len(i)-len(i.lstrip())
    
    #하위계층인지 체크
    if  a > before:
               
        rm_idx_list.append(ix-1)  # 해당 항목이 앞선항목의 하위항목에 해당된다면, 이전 항목의 row index를 저장하라
 

        #계층컬럼값 채우기
        for j in hier_num: 

            if j == a:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = i.strip()
                
                break


            else:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = df2.iloc[ix-1,b].strip()
        
        
        
        
        before = a



    else:   
        
        
        #계층컬럼값 채우기
        for j in hier_num: 

            if j == a:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = i.strip()
                
                break


            else:

                b = df2.columns.tolist().index(a_col[hier_num.index(j)])
                df2.iloc[ix ,b] = df2.iloc[ix-1,b].strip()
                
                
        
        before = a
        
        
        

        

# 실행 : output -> DB에 저장될  " bs_table ""  생성


preprocessing(df2,rm_idx_list,a_col)

# %%
bs_table
# Out:
#                               항목명 분류1      분류2                   분류3      분기  \
# 0                        현금및현금성자산  자산     유동자산              현금및현금성자산  제 50 기
# 1                          단기금융상품  자산     유동자산                단기금융상품  제 50 기
# 2                            매출채권  자산     유동자산                  매출채권  제 50 기
# 3                             미수금  자산     유동자산                   미수금  제 50 기
# 4                             선급금  자산     유동자산                   선급금  제 50 기
# 5                            선급비용  자산     유동자산                  선급비용  제 50 기
# 6                            재고자산  자산     유동자산                  재고자산  제 50 기
# 7                          기타유동자산  자산     유동자산                기타유동자산  제 50 기
# 8                        매각예정분류자산  자산     유동자산              매각예정분류자산  제 50 기
# 9                      장기매도가능금융자산  자산    비유동자산            장기매도가능금융자산  제 50 기
# 10                기타포괄손익-공정가치금융자산  자산    비유동자산       기타포괄손익-공정가치금융자산  제 50 기
# 11                  당기손익-공정가치금융자산  자산    비유동자산         당기손익-공정가치금융자산  제 50 기
# 12           종속기업, 관계기업 및 공동기업 투자  자산    비유동자산  종속기업, 관계기업 및 공동기업 투자  제 50 기
# 13                           유형자산  자산    비유동자산                  유형자산  제 50 기
# 14                           무형자산  자산    비유동자산                  무형자산  제 50 기
# 15                         장기선급비용  자산    비유동자산                장기선급비용  제 50 기
# 16                        순확정급여자산  자산    비유동자산               순확정급여자산  제 50 기
# 17                        이연법인세자산  자산    비유동자산               이연법인세자산  제 50 기
# 18                        기타비유동자산  자산    비유동자산               기타비유동자산  제 50 기
# 19                           매입채무  부채     유동부채                  매입채무  제 50 기
# 20                          단기차입금  부채     유동부채                 단기차입금  제 50 기
# 21                           미지급금  부채     유동부채                  미지급금  제 50 기
# 22                            선수금  부채     유동부채                   선수금  제 50 기
# 23                            예수금  부채     유동부채                   예수금  제 50 기
# 24                          미지급비용  부채     유동부채                 미지급비용  제 50 기
# 25                         미지급법인세  부채     유동부채                미지급법인세  제 50 기
# 26                        유동성장기부채  부채     유동부채               유동성장기부채  제 50 기
# 27                           충당부채  부채     유동부채                  충당부채  제 50 기
# 28                         기타유동부채  부채     유동부채                기타유동부채  제 50 기
# 29                             사채  부채    비유동부채                    사채  제 50 기
# ..                            ...  ..      ...                   ...     ...
# 84                       매각예정분류자산  자산     유동자산              매각예정분류자산  제 48 기
# 85                     장기매도가능금융자산  자산    비유동자산            장기매도가능금융자산  제 48 기
# 86                기타포괄손익-공정가치금융자산  자산    비유동자산       기타포괄손익-공정가치금융자산  제 48 기
# 87                  당기손익-공정가치금융자산  자산    비유동자산         당기손익-공정가치금융자산  제 48 기
# 88           종속기업, 관계기업 및 공동기업 투자  자산    비유동자산  종속기업, 관계기업 및 공동기업 투자  제 48 기
# 89                           유형자산  자산    비유동자산                  유형자산  제 48 기
# 90                           무형자산  자산    비유동자산                  무형자산  제 48 기
# 91                         장기선급비용  자산    비유동자산                장기선급비용  제 48 기
# 92                        순확정급여자산  자산    비유동자산               순확정급여자산  제 48 기
# 93                        이연법인세자산  자산    비유동자산               이연법인세자산  제 48 기
# 94                        기타비유동자산  자산    비유동자산               기타비유동자산  제 48 기
# 95                           매입채무  부채     유동부채                  매입채무  제 48 기
# 96                          단기차입금  부채     유동부채                 단기차입금  제 48 기
# 97                           미지급금  부채     유동부채                  미지급금  제 48 기
# 98                            선수금  부채     유동부채                   선수금  제 48 기
# 99                            예수금  부채     유동부채                   예수금  제 48 기
# 100                         미지급비용  부채     유동부채                 미지급비용  제 48 기
# 101                        미지급법인세  부채     유동부채                미지급법인세  제 48 기
# 102                       유동성장기부채  부채     유동부채               유동성장기부채  제 48 기
# 103                          충당부채  부채     유동부채                  충당부채  제 48 기
# 104                        기타유동부채  부채     유동부채                기타유동부채  제 48 기
# 105                            사채  부채    비유동부채                    사채  제 48 기
# 106                        장기미지급금  부채    비유동부채                장기미지급금  제 48 기
# 107                        장기충당부채  부채    비유동부채                장기충당부채  제 48 기
# 108                       기타비유동부채  부채    비유동부채               기타비유동부채  제 48 기
# 109                        우선주자본금  자본      자본금                우선주자본금  제 48 기
# 110                        보통주자본금  자본      자본금                보통주자본금  제 48 기
# 111                       주식발행초과금  자본  주식발행초과금                        제 48 기
# 112                         이익잉여금  자본    이익잉여금                        제 48 기
# 113                        기타자본항목  자본   기타자본항목                        제 48 기
#
#             금액
# 0      2607957
# 1     34113871
# 2     24933267
# 3      1515079
# 4       807262
# 5      2230628
# 6     12440951
# 7      1390440
# 8
# 9
# 10     1098565
# 11        7413
# 12    55959745
# 13    70602493
# 14     2901476
# 15     4108410
# 16      562356
# 17      654456
# 18     3086988
# 19     7315631
# 20    10353873
# 21     8385752
# 22      214615
# 23      572702
# 24     6129837
# 25     7925887
# 26        5440
# 27     2135314
# 28      106002
# 29       43516
# ..         ...
# 84      283690
# 85      913989
# 86
# 87
# 88    48743079
# 89    47228830
# 90     2891844
# 91     3507399
# 92      557091
# 93      110239
# 94      869360
# 95     6162650
# 96     9061167
# 97     7635740
# 98      200445
# 99      389528
# 100    6284646
# 101    2055829
# 102       5854
# 103    2221717
# 104      58546
# 105      58542
# 106    2808460
# 107     312467
# 108        606
# 109     119467
# 110     778047
# 111    4403893
# 112  140747574
# 113   -8502219
#
# [114 rows x 6 columns]

# %%
bs_table.to_csv('C:/DATA/BS_TABLE.csv',index=True , header =True,encoding='ms949')
